# %%
import config

# %%
import spotipy
import json
import pprint
from bs4 import BeautifulSoup
import requests
import pandas as pd
import numpy as np
from pyjarowinkler import distance
from spotipy.oauth2 import SpotifyClientCredentials


#Initialize SpotiPy with user credentias
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id= config.c_id,
                                                           client_secret= config.c_se))

# %% [markdown]
# ### Getting playlists

# %%
# locating playlist
playlist_country = sp.user_playlist_tracks("spotify", "3RPaWvjgg1SAi8oIh09Irp",market="GB")
playlist_rock = sp.user_playlist_tracks("spotify", "7KMtxb9kh3TtVvJTdLtJ2K",market="GB")
playlist_house = sp.user_playlist_tracks("spotify", "4VXFwpNvQysB8yS6E2t2ls",market="GB")
playlist_classicals = sp.user_playlist_tracks("spotify", "1h0CEZCm6IbFTbxThn6Xcs",market="GB")
playlist_dance = sp.user_playlist_tracks("spotify", "794tEP1QrKMcaQcFmEyFst",market="GB")
playlist_hiphop = sp.user_playlist_tracks("spotify", "0agbFCQZvK4q9WR0d4Iqcj",market="GB")
playlist_pop = sp.user_playlist_tracks("spotify", "2YRe7HRKNRvXdJBp9nXFza",market="GB")
playlist_jazz = sp.user_playlist_tracks("spotify", "7g2KyiE9RI5F1fV60OIUu4",market="GB")

# %% [markdown]
# ### Getting tracks

# %%
track=[]

# %%
# extracting tracks from playlist
def get_playlist_tracks(username, playlist_id):
    results = sp.user_playlist_tracks(username,playlist_id,market="GB")
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

# %%
tracks_country = get_playlist_tracks("username", "3RPaWvjgg1SAi8oIh09Irp")
tracks_country
# Out:
# [{'added_at': '2019-05-20T13:18:34Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/maddyburk'},
#    'href': 'https://api.spotify.com/v1/users/maddyburk',
#    'id': 'maddyburk',
#    'type': 'user',
#    'uri': 'spotify:user:maddyburk'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7dNsHhGeGU5MV01r06O8gK'},
#       'href': 'https://api.spotify.com/v1/artists/7dNsHhGeGU5MV01r06O8gK',
#       'id': '7dNsHhGeGU5MV01r06O8gK',
#       'name': 'Patsy Cline',
#       'type': 'artist',
#       'uri': 'spotify:artist:7dNsHhGeGU5MV01r06O8gK'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/54Ykk8Gg8TuHjLbYvErsKh'},
#     'href': 'https://api.spotify.com/v1/albums/54Ykk8Gg8TuHjLbYvErsKh',
#     'id': '54Ykk8Gg8TuHjLbYvErsKh',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2736fda96b0954b958ee44c8efc',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e026fda96b0954b958ee44c8efc',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048516fda96b0954b958ee44c8efc',
#       'width': 64}],
#     'name': 'Showcase',
#     'release_date': '1961-11-27',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:54Ykk8Gg8TuHjLbYvErsKh'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7dNsHhGeGU5MV01r06O8gK'},
#      'href': 'https://api.spotify.com/v1/artists/7dNsHhGeGU5MV01r06O8gK',
#      'id': '7dNsHhGeGU5MV01r06O8gK',
#      'name': 'Patsy Cline',
#      'type': 'artist',
#      'uri': 'spotify:artist:7dNsHhGeGU5MV01r06O8gK'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/6CXezToiGS8K6jr9kr8Muv'},
#      'href': 'https://api.spotify.com/v1/artists/6CXezToiGS8K6jr9kr8Muv',
#      'id': '6CXezToiGS8K6jr9kr8Muv',
#      'name': 'The Jordanaires',
#      'type': 'artist',
#      'uri': 'spotify:artist:6CXezToiGS8K6jr9kr8Muv'}],
#    'disc_number': 1,
#    'duration_ms': 164573,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USMC16147347'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3zpj9dvJABiyMrmLCPw6i8'},
#    'href': 'https://api.spotify.com/v1/tracks/3zpj9dvJABiyMrmLCPw6i8',
#    'id': '3zpj9dvJABiyMrmLCPw6i8',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Crazy - Single Version',
#    'popularity': 69,
#    'preview_url': None,
#    'track': True,
#    'track_number': 7,
#    'type': 'track',
#    'uri': 'spotify:track:3zpj9dvJABiyMrmLCPw6i8'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2019-05-20T13:20:16Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/maddyburk'},
#    'href': 'https://api.spotify.com/v1/users/maddyburk',
#    'id': 'maddyburk',
#    'type': 'user',
#    'uri': 'spotify:user:maddyburk'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6kACVPfCOnqzgfEF5ryl0x'},
#       'href': 'https://api.spotify.com/v1/artists/6kACVPfCOnqzgfEF5ryl0x',
#       'id': '6kACVPfCOnqzgfEF5ryl0x',
#       'name': 'Johnny Cash',
#       'type': 'artist',
#       'uri': 'spotify:artist:6kACVPfCOnqzgfEF5ryl0x'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0X7AlTPtEDf0Kv1QqYQwlU'},
#     'href': 'https://api.spotify.com/v1/albums/0X7AlTPtEDf0Kv1QqYQwlU',
#     'id': '0X7AlTPtEDf0Kv1QqYQwlU',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27323cf966c060364cec9424e02',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0223cf966c060364cec9424e02',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485123cf966c060364cec9424e02',
#       'width': 64}],
#     'name': 'Sings Hank Williams',
#     'release_date': '1960-01-01',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:0X7AlTPtEDf0Kv1QqYQwlU'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6kACVPfCOnqzgfEF5ryl0x'},
#      'href': 'https://api.spotify.com/v1/artists/6kACVPfCOnqzgfEF5ryl0x',
#      'id': '6kACVPfCOnqzgfEF5ryl0x',
#      'name': 'Johnny Cash',
#      'type': 'artist',
#      'uri': 'spotify:artist:6kACVPfCOnqzgfEF5ryl0x'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/3iGdenNgbzOak86BHrx0Nt'},
#      'href': 'https://api.spotify.com/v1/artists/3iGdenNgbzOak86BHrx0Nt',
#      'id': '3iGdenNgbzOak86BHrx0Nt',
#      'name': 'The Tennessee Two',
#      'type': 'artist',
#      'uri': 'spotify:artist:3iGdenNgbzOak86BHrx0Nt'}],
#    'disc_number': 1,
#    'duration_ms': 168554,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USSE60070036'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/121sjkub4p4zcFNozkKnQD'},
#    'href': 'https://api.spotify.com/v1/tracks/121sjkub4p4zcFNozkKnQD',
#    'id': '121sjkub4p4zcFNozkKnQD',
#    'is_local': False,
#    'is_playable': True,
#    'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/0Avmi9t3sOcaGSs1DSbgDg'},
#     'href': 'https://api.spotify.com/v1/tracks/0Avmi9t3sOcaGSs1DSbgDg',
#     'id': '0Avmi9t3sOcaGSs1DSbgDg',
#     'type': 'track',
#     'uri': 'spotify:track:0Avmi9t3sOcaGSs1DSbgDg'},
#    'name': 'Folsom Prison Blues',
#    'popularity': 57,
#    'preview_url': None,
#    'track': True,
#    'track_number': 7,
#    'type': 'track',
#    'uri': 'spotify:track:121sjkub4p4zcFNozkKnQD'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2019-05-20T13:20:30Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/maddyburk'},
#    'href': 'https://api.spotify.com/v1/users/maddyburk',
#    'id': 'maddyburk',
#    'type': 'user',
#    'uri': 'spotify:user:maddyburk'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/32vWCbZh0xZ4o9gkz4PsEU'},
#       'href': 'https://api.spotify.com/v1/artists/32vWCbZh0xZ4o9gkz4PsEU',
#       'id': '32vWCbZh0xZ4o9gkz4PsEU',
#       'name': 'Dolly Parton',
#       'type': 'artist',
#       'uri': 'spotify:artist:32vWCbZh0xZ4o9gkz4PsEU'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5DyOxuvdSmTSNAmkfcsBsj'},
#     'href': 'https://api.spotify.com/v1/albums/5DyOxuvdSmTSNAmkfcsBsj',
#     'id': '5DyOxuvdSmTSNAmkfcsBsj',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27326399936751b54c7e9782324',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0226399936751b54c7e9782324',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485126399936751b54c7e9782324',
#       'width': 64}],
#     'name': 'Jolene',
#     'release_date': '1974-02-04',
#     'release_date_precision': 'day',
#     'total_tracks': 10,
#     'type': 'album',
#     'uri': 'spotify:album:5DyOxuvdSmTSNAmkfcsBsj'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/32vWCbZh0xZ4o9gkz4PsEU'},
#      'href': 'https://api.spotify.com/v1/artists/32vWCbZh0xZ4o9gkz4PsEU',
#      'id': '32vWCbZh0xZ4o9gkz4PsEU',
#      'name': 'Dolly Parton',
#      'type': 'artist',
#      'uri': 'spotify:artist:32vWCbZh0xZ4o9gkz4PsEU'}],
#    'disc_number': 1,
#    'duration_ms': 176093,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USRN17300007'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6nRvgo4ySezQKD1D7NIqAu'},
#    'href': 'https://api.spotify.com/v1/tracks/6nRvgo4ySezQKD1D7NIqAu',
#    'id': '6nRvgo4ySezQKD1D7NIqAu',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'I Will Always Love You',
#    'popularity': 64,
#    'preview_url': 'https://p.scdn.co/mp3-preview/fbff57f3300f9303d4f5fbe876fcc15ed7ee564d?cid=48288ce6ec40441ab533827580f710b0',
#    'track': True,
#    'track_number': 6,
#    'type': 'track',
#    'uri': 'spotify:track:6nRvgo4ySezQKD1D7NIqAu'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2019-05-20T13:20:51Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/maddyburk'},
#    'href': 'https://api.spotify.com/v1/users/maddyburk',
#    'id': 'maddyburk',
#    'type': 'user',
#    'uri': 'spotify:user:maddyburk'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2IvkS5MXK0vPGnwyJsrEyV'},
#       'href': 'https://api.spotify.com/v1/artists/2IvkS5MXK0vPGnwyJsrEyV',
#       'id': '2IvkS5MXK0vPGnwyJsrEyV',
#       'name': 'Eric Church',
#       'type': 'artist',
#       'uri': 'spotify:artist:2IvkS5MXK0vPGnwyJsrEyV'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5dtw6CoMhbrSj01YUvdQOF'},
#     'href': 'https://api.spotify.com/v1/albums/5dtw6CoMhbrSj01YUvdQOF',
#     'id': '5dtw6CoMhbrSj01YUvdQOF',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273c1bc36faa8afff2b5273490b',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02c1bc36faa8afff2b5273490b',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851c1bc36faa8afff2b5273490b',
#       'width': 64}],
#     'name': 'Chief',
#     'release_date': '2011-01-01',
#     'release_date_precision': 'day',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:5dtw6CoMhbrSj01YUvdQOF'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2IvkS5MXK0vPGnwyJsrEyV'},
#      'href': 'https://api.spotify.com/v1/artists/2IvkS5MXK0vPGnwyJsrEyV',
#      'id': '2IvkS5MXK0vPGnwyJsrEyV',
#      'name': 'Eric Church',
#      'type': 'artist',
#      'uri': 'spotify:artist:2IvkS5MXK0vPGnwyJsrEyV'}],
#    'disc_number': 1,
#    'duration_ms': 263386,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USCN11100116'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/05ZACkzW8YbRq3eFgIfSNB'},
#    'href': 'https://api.spotify.com/v1/tracks/05ZACkzW8YbRq3eFgIfSNB',
#    'id': '05ZACkzW8YbRq3eFgIfSNB',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Springsteen',
#    'popularity': 74,
#    'preview_url': None,
#    'track': True,
#    'track_number': 9,
#    'type': 'track',
#    'uri': 'spotify:track:05ZACkzW8YbRq3eFgIfSNB'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2019-05-20T13:21:09Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/maddyburk'},
#    'href': 'https://api.spotify.com/v1/users/maddyburk',
#    'id': 'maddyburk',
#    'type': 'user',
#    'uri': 'spotify:user:maddyburk'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2OpqcUtj10HHvGG6h9VYC5'},
#       'href': 'https://api.spotify.com/v1/artists/2OpqcUtj10HHvGG6h9VYC5',
#       'id': '2OpqcUtj10HHvGG6h9VYC5',
#       'name': 'George Jones',
#       'type': 'artist',
#       'uri': 'spotify:artist:2OpqcUtj10HHvGG6h9VYC5'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4LN572kqxZfNyNgt2rGGKR'},
#     'href': 'https://api.spotify.com/v1/albums/4LN572kqxZfNyNgt2rGGKR',
#     'id': '4LN572kqxZfNyNgt2rGGKR',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273333c4f43127c11f3e748e367',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02333c4f43127c11f3e748e367',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851333c4f43127c11f3e748e367',
#       'width': 64}],
#     'name': 'Super Hits',
#     'release_date': '1987-01-01',
#     'release_date_precision': 'day',
#     'total_tracks': 10,
#     'type': 'album',
#     'uri': 'spotify:album:4LN572kqxZfNyNgt2rGGKR'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2OpqcUtj10HHvGG6h9VYC5'},
#      'href': 'https://api.spotify.com/v1/artists/2OpqcUtj10HHvGG6h9VYC5',
#      'id': '2OpqcUtj10HHvGG6h9VYC5',
#      'name': 'George Jones',
#      'type': 'artist',
#      'uri': 'spotify:artist:2OpqcUtj10HHvGG6h9VYC5'}],
#    'disc_number': 1,
#    'duration_ms': 195333,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USSM19903017'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6qMgx8ys4MNNxypaIvbG0i'},
#    'href': 'https://api.spotify.com/v1/tracks/6qMgx8ys4MNNxypaIvbG0i',
#    'id': '6qMgx8ys4MNNxypaIvbG0i',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'He Stopped Loving Her Today',
#    'popularity': 56,
#    'preview_url': 'https://p.scdn.co/mp3-preview/334c331f75a47eea368a6b2b06b384d0c77279f9?cid=48288ce6ec40441ab533827580f710b0',
#    'track': True,
#    'track_number': 7,
#    'type': 'track',
#    'uri': 'spotify:track:6qMgx8ys4MNNxypaIvbG0i'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2019-05-20T13:21:25Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/maddyburk'},
#    'href': 'https://api.spotify.com/v1/users/maddyburk',
#    'id': 'maddyburk',
#    'type': 'user',
#    'uri': 'spotify:user:maddyburk'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/12d4iIvTOk7JkI6ecvc3ca'},
#       'href': 'https://api.spotify.com/v1/artists/12d4iIvTOk7JkI6ecvc3ca',
#       'id': '12d4iIvTOk7JkI6ecvc3ca',
#       'name': 'The Charlie Daniels Band',
#       'type': 'artist',
#       'uri': 'spotify:artist:12d4iIvTOk7JkI6ecvc3ca'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/7H5LNy2PyN3VLUm5nnMZEc'},
#     'href': 'https://api.spotify.com/v1/albums/7H5LNy2PyN3VLUm5nnMZEc',
#     'id': '7H5LNy2PyN3VLUm5nnMZEc',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27382f846c52535bb65ab1d1a54',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0282f846c52535bb65ab1d1a54',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485182f846c52535bb65ab1d1a54',
#       'width': 64}],
#     'name': 'A Decade Of Hits',
#     'release_date': '1973',
#     'release_date_precision': 'year',
#     'total_tracks': 10,
#     'type': 'album',
#     'uri': 'spotify:album:7H5LNy2PyN3VLUm5nnMZEc'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/12d4iIvTOk7JkI6ecvc3ca'},
#      'href': 'https://api.spotify.com/v1/artists/12d4iIvTOk7JkI6ecvc3ca',
#      'id': '12d4iIvTOk7JkI6ecvc3ca',
#      'name': 'The Charlie Daniels Band',
#      'type': 'artist',
#      'uri': 'spotify:artist:12d4iIvTOk7JkI6ecvc3ca'}],
#    'disc_number': 1,
#    'duration_ms': 214866,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USSM17900810'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/383Xl5QTigwj3QiA3Qc6S7'},
#    'href': 'https://api.spotify.com/v1/tracks/383Xl5QTigwj3QiA3Qc6S7',
#    'id': '383Xl5QTigwj3QiA3Qc6S7',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'The Devil Went Down to Georgia',
#    'popularity': 71,
#    'preview_url': 'https://p.scdn.co/mp3-preview/6b9c774c746cbb0c2b78bc0b3c88e09f937eddce?cid=48288ce6ec40441ab533827580f710b0',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:383Xl5QTigwj3QiA3Qc6S7'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2019-05-20T13:21:39Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/maddyburk'},
#    'href': 'https://api.spotify.com/v1/users/maddyburk',
#    'id': 'maddyburk',
#    'type': 'user',
#    'uri': 'spotify:user:maddyburk'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'compilation',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1RP2UpEaRzkF0Id3JigqD8'},
#       'href': 'https://api.spotify.com/v1/artists/1RP2UpEaRzkF0Id3JigqD8',
#       'id': '1RP2UpEaRzkF0Id3JigqD8',
#       'name': 'Roger Miller',
#       'type': 'artist',
#       'uri': 'spotify:artist:1RP2UpEaRzkF0Id3JigqD8'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/5ORQsfsA6cGFG70iut52tb'},
#     'href': 'https://api.spotify.com/v1/albums/5ORQsfsA6cGFG70iut52tb',
#     'id': '5ORQsfsA6cGFG70iut52tb',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27326b6e5bb0dc1e2cb63296a3f',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0226b6e5bb0dc1e2cb63296a3f',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485126b6e5bb0dc1e2cb63296a3f',
#       'width': 64}],
#     'name': 'The Best Of Roger Miller Volume Two: King Of The Road',
#     'release_date': '1992-08-04',
#     'release_date_precision': 'day',
#     'total_tracks': 20,
#     'type': 'album',
#     'uri': 'spotify:album:5ORQsfsA6cGFG70iut52tb'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1RP2UpEaRzkF0Id3JigqD8'},
#      'href': 'https://api.spotify.com/v1/artists/1RP2UpEaRzkF0Id3JigqD8',
#      'id': '1RP2UpEaRzkF0Id3JigqD8',
#      'name': 'Roger Miller',
#      'type': 'artist',
#      'uri': 'spotify:artist:1RP2UpEaRzkF0Id3JigqD8'}],
#    'disc_number': 1,
#    'duration_ms': 146466,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USPR36407083'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/0tm2gY77p2X7BsSWRq0cBk'},
#    'href': 'https://api.spotify.com/v1/tracks/0tm2gY77p2X7BsSWRq0cBk',
#    'id': '0tm2gY77p2X7BsSWRq0cBk',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'King Of The Road',
#    'popularity': 37,
#    'preview_url': None,
#    'track': True,
#    'track_number': 7,
#    'type': 'track',
#    'uri': 'spotify:track:0tm2gY77p2X7BsSWRq0cBk'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2019-05-20T13:21:52Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/maddyburk'},
#    'href': 'https://api.spotify.com/v1/users/maddyburk',
#    'id': 'maddyburk',
#    'type': 'user',
#    'uri': 'spotify:user:maddyburk'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3FfvYsEGaIb52QPXhg4DcH'},
#       'href': 'https://api.spotify.com/v1/artists/3FfvYsEGaIb52QPXhg4DcH',
#       'id': '3FfvYsEGaIb52QPXhg4DcH',
#       'name': 'Jason Aldean',
#       'type': 'artist',
#       'uri': 'spotify:artist:3FfvYsEGaIb52QPXhg4DcH'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1vwqf42OUqrGJtLFqixZUB'},
#     'href': 'https://api.spotify.com/v1/albums/1vwqf42OUqrGJtLFqixZUB',
#     'id': '1vwqf42OUqrGJtLFqixZUB',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27386a9267d77e76cb584b8db1e',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0286a9267d77e76cb584b8db1e',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485186a9267d77e76cb584b8db1e',
#       'width': 64}],
#     'name': 'My Kinda Party',
#     'release_date': '2010-11-02',
#     'release_date_precision': 'day',
#     'total_tracks': 15,
#     'type': 'album',
#     'uri': 'spotify:album:1vwqf42OUqrGJtLFqixZUB'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3FfvYsEGaIb52QPXhg4DcH'},
#      'href': 'https://api.spotify.com/v1/artists/3FfvYsEGaIb52QPXhg4DcH',
#      'id': '3FfvYsEGaIb52QPXhg4DcH',
#      'name': 'Jason Aldean',
#      'type': 'artist',
#      'uri': 'spotify:artist:3FfvYsEGaIb52QPXhg4DcH'}],
#    'disc_number': 1,
#    'duration_ms': 229413,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'US58E1000234'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7awFBRzXpFoy8YIm9zOb5s'},
#    'href': 'https://api.spotify.com/v1/tracks/7awFBRzXpFoy8YIm9zOb5s',
#    'id': '7awFBRzXpFoy8YIm9zOb5s',
#    'is_local': False,
#    'is_playable': True,
#    'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/2qYsSHsYkihWx043HVJQRV'},
#     'href': 'https://api.spotify.com/v1/tracks/2qYsSHsYkihWx043HVJQRV',
#     'id': '2qYsSHsYkihWx043HVJQRV',
#     'type': 'track',
#     'uri': 'spotify:track:2qYsSHsYkihWx043HVJQRV'},
#    'name': 'Dirt Road Anthem',
#    'popularity': 56,
#    'preview_url': 'https://p.scdn.co/mp3-preview/531818125c704ddd898e702d8e7f4b987c316850?cid=48288ce6ec40441ab533827580f710b0',
#    'track': True,
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:7awFBRzXpFoy8YIm9zOb5s'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2019-05-20T13:22:05Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/maddyburk'},
#    'href': 'https://api.spotify.com/v1/users/maddyburk',
#    'id': 'maddyburk',
#    'type': 'user',
#    'uri': 'spotify:user:maddyburk'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0Xi59sEw38vRvwleSAVqoo'},
#       'href': 'https://api.spotify.com/v1/artists/0Xi59sEw38vRvwleSAVqoo',
#       'id': '0Xi59sEw38vRvwleSAVqoo',
#       'name': 'Marty Robbins',
#       'type': 'artist',
#       'uri': 'spotify:artist:0Xi59sEw38vRvwleSAVqoo'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3kQpBS26lAj0A0VGl1snRl'},
#     'href': 'https://api.spotify.com/v1/albums/3kQpBS26lAj0A0VGl1snRl',
#     'id': '3kQpBS26lAj0A0VGl1snRl',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273084051346f432cc68a1279cd',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02084051346f432cc68a1279cd',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851084051346f432cc68a1279cd',
#       'width': 64}],
#     'name': 'Gunfighter Ballads And Trail Songs',
#     'release_date': '1959',
#     'release_date_precision': 'year',
#     'total_tracks': 15,
#     'type': 'album',
#     'uri': 'spotify:album:3kQpBS26lAj0A0VGl1snRl'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0Xi59sEw38vRvwleSAVqoo'},
#      'href': 'https://api.spotify.com/v1/artists/0Xi59sEw38vRvwleSAVqoo',
#      'id': '0Xi59sEw38vRvwleSAVqoo',
#      'name': 'Marty Robbins',
#      'type': 'artist',
#      'uri': 'spotify:artist:0Xi59sEw38vRvwleSAVqoo'}],
#    'disc_number': 1,
#    'duration_ms': 259306,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USSM15901202'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4f8hBeMXMvssn6HtFAtblo'},
#    'href': 'https://api.spotify.com/v1/tracks/4f8hBeMXMvssn6HtFAtblo',
#    'id': '4f8hBeMXMvssn6HtFAtblo',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'El Paso',
#    'popularity': 64,
#    'preview_url': 'https://p.scdn.co/mp3-preview/0bde321c4359f861ff60b39354607e4a97f2acd1?cid=48288ce6ec40441ab533827580f710b0',
#    'track': True,
#    'track_number': 10,
#    'type': 'track',
#    'uri': 'spotify:track:4f8hBeMXMvssn6HtFAtblo'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2019-05-20T13:22:15Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/maddyburk'},
#    'href': 'https://api.spotify.com/v1/users/maddyburk',
#    'id': 'maddyburk',
#    'type': 'user',
#    'uri': 'spotify:user:maddyburk'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7dNsHhGeGU5MV01r06O8gK'},
#       'href': 'https://api.spotify.com/v1/artists/7dNsHhGeGU5MV01r06O8gK',
#       'id': '7dNsHhGeGU5MV01r06O8gK',
#       'name': 'Patsy Cline',
#       'type': 'artist',
#       'uri': 'spotify:artist:7dNsHhGeGU5MV01r06O8gK'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/54Ykk8Gg8TuHjLbYvErsKh'},
#     'href': 'https://api.spotify.com/v1/albums/54Ykk8Gg8TuHjLbYvErsKh',
#     'id': '54Ykk8Gg8TuHjLbYvErsKh',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2736fda96b0954b958ee44c8efc',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e026fda96b0954b958ee44c8efc',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048516fda96b0954b958ee44c8efc',
#       'width': 64}],
#     'name': 'Showcase',
#     'release_date': '1961-11-27',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:54Ykk8Gg8TuHjLbYvErsKh'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7dNsHhGeGU5MV01r06O8gK'},
#      'href': 'https://api.spotify.com/v1/artists/7dNsHhGeGU5MV01r06O8gK',
#      'id': '7dNsHhGeGU5MV01r06O8gK',
#      'name': 'Patsy Cline',
#      'type': 'artist',
#      'uri': 'spotify:artist:7dNsHhGeGU5MV01r06O8gK'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/6CXezToiGS8K6jr9kr8Muv'},
#      'href': 'https://api.spotify.com/v1/artists/6CXezToiGS8K6jr9kr8Muv',
#      'id': '6CXezToiGS8K6jr9kr8Muv',
#      'name': 'The Jordanaires',
#      'type': 'artist',
#      'uri': 'spotify:artist:6CXezToiGS8K6jr9kr8Muv'}],
#    'disc_number': 1,
#    'duration_ms': 171333,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USMC16048707'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6zFsz86nAj5gcvzyVqNL3k'},
#    'href': 'https://api.spotify.com/v1/tracks/6zFsz86nAj5gcvzyVqNL3k',
#    'id': '6zFsz86nAj5gcvzyVqNL3k',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'I Fall To Pieces - Single Version',
#    'popularity': 65,
#    'preview_url': None,
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:6zFsz86nAj5gcvzyVqNL3k'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2019-05-20T13:22:54Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/maddyburk'},
#    'href': 'https://api.spotify.com/v1/users/maddyburk',
#    'id': 'maddyburk',
#    'type': 'user',
#    'uri': 'spotify:user:maddyburk'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'compilation',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#       'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#       'id': '0LyfQWJT6nXafLPZqxe9Of',
#       'name': 'Various Artists',
#       'type': 'artist',
#       'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3LP0jc2J6fvhpVTKWzvFUk'},
#     'href': 'https://api.spotify.com/v1/albums/3LP0jc2J6fvhpVTKWzvFUk',
#     'id': '3LP0jc2J6fvhpVTKWzvFUk',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2737f570d8b2e794f1493dca2ca',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e027f570d8b2e794f1493dca2ca',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048517f570d8b2e794f1493dca2ca',
#       'width': 64}],
#     'name': 'Forrest Gump - The Soundtrack',
#     'release_date': '2001-10-02',
#     'release_date_precision': 'day',
#     'total_tracks': 34,
#     'type': 'album',
#     'uri': 'spotify:album:3LP0jc2J6fvhpVTKWzvFUk'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5W5bDNCqJ1jbCgTxDD0Cb3'},
#      'href': 'https://api.spotify.com/v1/artists/5W5bDNCqJ1jbCgTxDD0Cb3',
#      'id': '5W5bDNCqJ1jbCgTxDD0Cb3',
#      'name': 'Willie Nelson',
#      'type': 'artist',
#      'uri': 'spotify:artist:5W5bDNCqJ1jbCgTxDD0Cb3'}],
#    'disc_number': 2,
#    'duration_ms': 148106,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USSM10107320'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3MpK9vnxxgYvh0CNeGvx6G'},
#    'href': 'https://api.spotify.com/v1/tracks/3MpK9vnxxgYvh0CNeGvx6G',
#    'id': '3MpK9vnxxgYvh0CNeGvx6G',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'On the Road Again',
#    'popularity': 52,
#    'preview_url': 'https://p.scdn.co/mp3-preview/b28e80fb9f5d5e26a6f7435bd9a808ada81e51fa?cid=48288ce6ec40441ab533827580f710b0',
#    'track': True,
#    'track_number': 16,
#    'type': 'track',
#    'uri': 'spotify:track:3MpK9vnxxgYvh0CNeGvx6G'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2019-05-20T13:23:07Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/maddyburk'},
#    'href': 'https://api.spotify.com/v1/users/maddyburk',
#    'id': 'maddyburk',
#    'type': 'user',
#    'uri': 'spotify:user:maddyburk'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6rJqqRce0Kvo2dJUXoHleC'},
#       'href': 'https://api.spotify.com/v1/artists/6rJqqRce0Kvo2dJUXoHleC',
#       'id': '6rJqqRce0Kvo2dJUXoHleC',
#       'name': 'Alabama',
#       'type': 'artist',
#       'uri': 'spotify:artist:6rJqqRce0Kvo2dJUXoHleC'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4oFLKch6Zh0YanY9Uj2s8z'},
#     'href': 'https://api.spotify.com/v1/albums/4oFLKch6Zh0YanY9Uj2s8z',
#     'id': '4oFLKch6Zh0YanY9Uj2s8z',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27348d7076be8ca3d2ec5e688d8',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0248d7076be8ca3d2ec5e688d8',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485148d7076be8ca3d2ec5e688d8',
#       'width': 64}],
#     'name': 'Ultimate Alabama 20 # 1 Hits',
#     'release_date': '2004-10-08',
#     'release_date_precision': 'day',
#     'total_tracks': 20,
#     'type': 'album',
#     'uri': 'spotify:album:4oFLKch6Zh0YanY9Uj2s8z'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6rJqqRce0Kvo2dJUXoHleC'},
#      'href': 'https://api.spotify.com/v1/artists/6rJqqRce0Kvo2dJUXoHleC',
#      'id': '6rJqqRce0Kvo2dJUXoHleC',
#      'name': 'Alabama',
#      'type': 'artist',
#      'uri': 'spotify:artist:6rJqqRce0Kvo2dJUXoHleC'}],
#    'disc_number': 1,
#    'duration_ms': 218613,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USRN10400080'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7BjmEKAVTnJNkRNaUzBy2K'},
#    'href': 'https://api.spotify.com/v1/tracks/7BjmEKAVTnJNkRNaUzBy2K',
#    'id': '7BjmEKAVTnJNkRNaUzBy2K',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Mountain Music',
#    'popularity': 63,
#    'preview_url': 'https://p.scdn.co/mp3-preview/6f8b88ddd39655d9a5659d099a235376f17cc194?cid=48288ce6ec40441ab533827580f710b0',
#    'track': True,
#    'track_number': 6,
#    'type': 'track',
#    'uri': 'spotify:track:7BjmEKAVTnJNkRNaUzBy2K'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2019-05-20T13:23:32Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/maddyburk'},
#    'href': 'https://api.spotify.com/v1/users/maddyburk',
#    'id': 'maddyburk',
#    'type': 'user',
#    'uri': 'spotify:user:maddyburk'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3grHWM9bx2E9vwJCdlRv9O'},
#       'href': 'https://api.spotify.com/v1/artists/3grHWM9bx2E9vwJCdlRv9O',
#       'id': '3grHWM9bx2E9vwJCdlRv9O',
#       'name': 'Kenny Chesney',
#       'type': 'artist',
#       'uri': 'spotify:artist:3grHWM9bx2E9vwJCdlRv9O'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/67qNNUSHekqSliS7Q1XZj6'},
#     'href': 'https://api.spotify.com/v1/albums/67qNNUSHekqSliS7Q1XZj6',
#     'id': '67qNNUSHekqSliS7Q1XZj6',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273a7e1e1bc8ddf0e767c056ea6',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02a7e1e1bc8ddf0e767c056ea6',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851a7e1e1bc8ddf0e767c056ea6',
#       'width': 64}],
#     'name': 'Everywhere We Go',
#     'release_date': '1999-02-26',
#     'release_date_precision': 'day',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:67qNNUSHekqSliS7Q1XZj6'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3grHWM9bx2E9vwJCdlRv9O'},
#      'href': 'https://api.spotify.com/v1/artists/3grHWM9bx2E9vwJCdlRv9O',
#      'id': '3grHWM9bx2E9vwJCdlRv9O',
#      'name': 'Kenny Chesney',
#      'type': 'artist',
#      'uri': 'spotify:artist:3grHWM9bx2E9vwJCdlRv9O'}],
#    'disc_number': 1,
#    'duration_ms': 188200,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USBN19700118'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2HmMklpgK8vGCpJmPpz1yG'},
#    'href': 'https://api.spotify.com/v1/tracks/2HmMklpgK8vGCpJmPpz1yG',
#    'id': '2HmMklpgK8vGCpJmPpz1yG',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'How Forever Feels',
#    'popularity': 60,
#    'preview_url': 'https://p.scdn.co/mp3-preview/53e2b795c9005d82de61565ad469c56f593980e1?cid=48288ce6ec40441ab533827580f710b0',
#    'track': True,
#    'track_number': 2,
#    'type': 'track',
#    'uri': 'spotify:track:2HmMklpgK8vGCpJmPpz1yG'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2019-05-20T13:23:58Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/maddyburk'},
#    'href': 'https://api.spotify.com/v1/users/maddyburk',
#    'id': 'maddyburk',
#    'type': 'user',
#    'uri': 'spotify:user:maddyburk'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1LFKKuzn302wp15dYH28id'},
#       'href': 'https://api.spotify.com/v1/artists/1LFKKuzn302wp15dYH28id',
#       'id': '1LFKKuzn302wp15dYH28id',
#       'name': 'Tammy Wynette',
#       'type': 'artist',
#       'uri': 'spotify:artist:1LFKKuzn302wp15dYH28id'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4yyvXQaZrk45jH6tzvGPwg'},
#     'href': 'https://api.spotify.com/v1/albums/4yyvXQaZrk45jH6tzvGPwg',
#     'id': '4yyvXQaZrk45jH6tzvGPwg',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27336693e859838bda4321616db',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0236693e859838bda4321616db',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485136693e859838bda4321616db',
#       'width': 64}],
#     'name': 'Tears Of Fire: The 25th Anniversary Collection',
#     'release_date': '1964',
#     'release_date_precision': 'year',
#     'total_tracks': 67,
#     'type': 'album',
#     'uri': 'spotify:album:4yyvXQaZrk45jH6tzvGPwg'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1LFKKuzn302wp15dYH28id'},
#      'href': 'https://api.spotify.com/v1/artists/1LFKKuzn302wp15dYH28id',
#      'id': '1LFKKuzn302wp15dYH28id',
#      'name': 'Tammy Wynette',
#      'type': 'artist',
#      'uri': 'spotify:artist:1LFKKuzn302wp15dYH28id'}],
#    'disc_number': 1,
#    'duration_ms': 159760,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USSM16800038'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6xatfNMI8NkY5XxRHAeiS4'},
#    'href': 'https://api.spotify.com/v1/tracks/6xatfNMI8NkY5XxRHAeiS4',
#    'id': '6xatfNMI8NkY5XxRHAeiS4',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Stand By Your Man',
#    'popularity': 61,
#    'preview_url': 'https://p.scdn.co/mp3-preview/fa1131466c1b2f0cffcf7fd7b73d76950ebcb4bb?cid=48288ce6ec40441ab533827580f710b0',
#    'track': True,
#    'track_number': 14,
#    'type': 'track',
#    'uri': 'spotify:track:6xatfNMI8NkY5XxRHAeiS4'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2019-05-20T13:24:17Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/maddyburk'},
#    'href': 'https://api.spotify.com/v1/users/maddyburk',
#    'id': 'maddyburk',
#    'type': 'user',
#    'uri': 'spotify:user:maddyburk'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'compilation',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4mxWe1mtYIYfP040G38yvS'},
#       'href': 'https://api.spotify.com/v1/artists/4mxWe1mtYIYfP040G38yvS',
#       'id': '4mxWe1mtYIYfP040G38yvS',
#       'name': 'Alan Jackson',
#       'type': 'artist',
#       'uri': 'spotify:artist:4mxWe1mtYIYfP040G38yvS'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/26w8J2SKCxa80Bwq6G8ctN'},
#     'href': 'https://api.spotify.com/v1/albums/26w8J2SKCxa80Bwq6G8ctN',
#     'id': '26w8J2SKCxa80Bwq6G8ctN',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2739921515d1f6a08b5d4907014',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e029921515d1f6a08b5d4907014',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048519921515d1f6a08b5d4907014',
#       'width': 64}],
#     'name': '34 Number Ones',
#     'release_date': '2010-11-19',
#     'release_date_precision': 'day',
#     'total_tracks': 37,
#     'type': 'album',
#     'uri': 'spotify:album:26w8J2SKCxa80Bwq6G8ctN'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4mxWe1mtYIYfP040G38yvS'},
#      'href': 'https://api.spotify.com/v1/artists/4mxWe1mtYIYfP040G38yvS',
#      'id': '4mxWe1mtYIYfP040G38yvS',
#      'name': 'Alan Jackson',
#      'type': 'artist',
#      'uri': 'spotify:artist:4mxWe1mtYIYfP040G38yvS'}],
#    'disc_number': 1,
#    'duration_ms': 228733,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USAN21000121'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/26iYJEimPCE0ozDlpj0UFN'},
#    'href': 'https://api.spotify.com/v1/tracks/26iYJEimPCE0ozDlpj0UFN',
#    'id': '26iYJEimPCE0ozDlpj0UFN',
#    'is_local': False,
#    'is_playable': True,
#    'name': "Livin' On Love",
#    'popularity': 60,
#    'preview_url': 'https://p.scdn.co/mp3-preview/0b1f10512c58817e0539051a7906a31283a2e365?cid=48288ce6ec40441ab533827580f710b0',
#    'track': True,
#    'track_number': 16,
#    'type': 'track',
#    'uri': 'spotify:track:26iYJEimPCE0ozDlpj0UFN'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2019-05-20T13:24:27Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/maddyburk'},
#    'href': 'https://api.spotify.com/v1/users/maddyburk',
#    'id': 'maddyburk',
#    'type': 'user',
#    'uri': 'spotify:user:maddyburk'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'compilation',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6kACVPfCOnqzgfEF5ryl0x'},
#       'href': 'https://api.spotify.com/v1/artists/6kACVPfCOnqzgfEF5ryl0x',
#       'id': '6kACVPfCOnqzgfEF5ryl0x',
#       'name': 'Johnny Cash',
#       'type': 'artist',
#       'uri': 'spotify:artist:6kACVPfCOnqzgfEF5ryl0x'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0ucV57dbnqmrGv9d60r6X2'},
#     'href': 'https://api.spotify.com/v1/albums/0ucV57dbnqmrGv9d60r6X2',
#     'id': '0ucV57dbnqmrGv9d60r6X2',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273dfe4bfe695c4192e547e72c7',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02dfe4bfe695c4192e547e72c7',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851dfe4bfe695c4192e547e72c7',
#       'width': 64}],
#     'name': 'Ring Of Fire: The Best Of Johnny Cash',
#     'release_date': '1963-08-06',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:0ucV57dbnqmrGv9d60r6X2'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6kACVPfCOnqzgfEF5ryl0x'},
#      'href': 'https://api.spotify.com/v1/artists/6kACVPfCOnqzgfEF5ryl0x',
#      'id': '6kACVPfCOnqzgfEF5ryl0x',
#      'name': 'Johnny Cash',
#      'type': 'artist',
#      'uri': 'spotify:artist:6kACVPfCOnqzgfEF5ryl0x'}],
#    'disc_number': 1,
#    'duration_ms': 158426,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USSM11201688'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6YffUZJ2R06kyxyK6onezL'},
#    'href': 'https://api.spotify.com/v1/tracks/6YffUZJ2R06kyxyK6onezL',
#    'id': '6YffUZJ2R06kyxyK6onezL',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Ring of Fire',
#    'popularity': 72,
#    'preview_url': 'https://p.scdn.co/mp3-preview/e3bbba328a3227e0d1095f804cd73a634de8cd04?cid=48288ce6ec40441ab533827580f710b0',
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:6YffUZJ2R06kyxyK6onezL'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2019-05-20T13:24:39Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/maddyburk'},
#    'href': 'https://api.spotify.com/v1/users/maddyburk',
#    'id': 'maddyburk',
#    'type': 'user',
#    'uri': 'spotify:user:maddyburk'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6roFdX1y5BYSbp60OTJWMd'},
#       'href': 'https://api.spotify.com/v1/artists/6roFdX1y5BYSbp60OTJWMd',
#       'id': '6roFdX1y5BYSbp60OTJWMd',
#       'name': 'Tim McGraw',
#       'type': 'artist',
#       'uri': 'spotify:artist:6roFdX1y5BYSbp60OTJWMd'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0os1Gz3XMM6dduZSMxVuXs'},
#     'href': 'https://api.spotify.com/v1/albums/0os1Gz3XMM6dduZSMxVuXs',
#     'id': '0os1Gz3XMM6dduZSMxVuXs',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273e6b859b16a880b851822871d',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02e6b859b16a880b851822871d',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851e6b859b16a880b851822871d',
#       'width': 64}],
#     'name': 'Live Like You Were Dying',
#     'release_date': '2004-08-17',
#     'release_date_precision': 'day',
#     'total_tracks': 16,
#     'type': 'album',
#     'uri': 'spotify:album:0os1Gz3XMM6dduZSMxVuXs'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6roFdX1y5BYSbp60OTJWMd'},
#      'href': 'https://api.spotify.com/v1/artists/6roFdX1y5BYSbp60OTJWMd',
#      'id': '6roFdX1y5BYSbp60OTJWMd',
#      'name': 'Tim McGraw',
#      'type': 'artist',
#      'uri': 'spotify:artist:6roFdX1y5BYSbp60OTJWMd'}],
#    'disc_number': 1,
#    'duration_ms': 300333,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USCRB0406175'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7B1QliUMZv7gSTUGAfMRRD'},
#    'href': 'https://api.spotify.com/v1/tracks/7B1QliUMZv7gSTUGAfMRRD',
#    'id': '7B1QliUMZv7gSTUGAfMRRD',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Live Like You Were Dying',
#    'popularity': 70,
#    'preview_url': 'https://p.scdn.co/mp3-preview/9b73e1776132292a8014266a6530fd28c25bb743?cid=48288ce6ec40441ab533827580f710b0',
#    'track': True,
#    'track_number': 5,
#    'type': 'track',
#    'uri': 'spotify:track:7B1QliUMZv7gSTUGAfMRRD'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2019-05-20T13:24:53Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/maddyburk'},
#    'href': 'https://api.spotify.com/v1/users/maddyburk',
#    'id': 'maddyburk',
#    'type': 'user',
#    'uri': 'spotify:user:maddyburk'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'compilation',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1FClsNYBUoNFtGgzeG74dW'},
#       'href': 'https://api.spotify.com/v1/artists/1FClsNYBUoNFtGgzeG74dW',
#       'id': '1FClsNYBUoNFtGgzeG74dW',
#       'name': 'Hank Williams',
#       'type': 'artist',
#       'uri': 'spotify:artist:1FClsNYBUoNFtGgzeG74dW'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6zIYEv6soMoaZiypsHB5dd'},
#     'href': 'https://api.spotify.com/v1/albums/6zIYEv6soMoaZiypsHB5dd',
#     'id': '6zIYEv6soMoaZiypsHB5dd',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273bf7de449bfd768b5a1e3bdd0',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02bf7de449bfd768b5a1e3bdd0',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851bf7de449bfd768b5a1e3bdd0',
#       'width': 64}],
#     'name': '40 Greatest Hits',
#     'release_date': '1978-01-01',
#     'release_date_precision': 'day',
#     'total_tracks': 40,
#     'type': 'album',
#     'uri': 'spotify:album:6zIYEv6soMoaZiypsHB5dd'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1FClsNYBUoNFtGgzeG74dW'},
#      'href': 'https://api.spotify.com/v1/artists/1FClsNYBUoNFtGgzeG74dW',
#      'id': '1FClsNYBUoNFtGgzeG74dW',
#      'name': 'Hank Williams',
#      'type': 'artist',
#      'uri': 'spotify:artist:1FClsNYBUoNFtGgzeG74dW'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/6LF21o9Yfj4a16Rw38Vxml'},
#      'href': 'https://api.spotify.com/v1/artists/6LF21o9Yfj4a16Rw38Vxml',
#      'id': '6LF21o9Yfj4a16Rw38Vxml',
#      'name': 'Drifting Cowboys',
#      'type': 'artist',
#      'uri': 'spotify:artist:6LF21o9Yfj4a16Rw38Vxml'}],
#    'disc_number': 2,
#    'duration_ms': 163506,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USPR35202092'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/73HgnHCHDEZCmtMpEzxnO0'},
#    'href': 'https://api.spotify.com/v1/tracks/73HgnHCHDEZCmtMpEzxnO0',
#    'id': '73HgnHCHDEZCmtMpEzxnO0',
#    'is_local': False,
#    'is_playable': True,
#    'name': "Your Cheatin' Heart",
#    'popularity': 34,
#    'preview_url': None,
#    'track': True,
#    'track_number': 16,
#    'type': 'track',
#    'uri': 'spotify:track:73HgnHCHDEZCmtMpEzxnO0'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2019-05-20T13:25:13Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/maddyburk'},
#    'href': 'https://api.spotify.com/v1/users/maddyburk',
#    'id': 'maddyburk',
#    'type': 'user',
#    'uri': 'spotify:user:maddyburk'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/5J6L7N6B4nI1M5cwa29mQG'},
#       'href': 'https://api.spotify.com/v1/artists/5J6L7N6B4nI1M5cwa29mQG',
#       'id': '5J6L7N6B4nI1M5cwa29mQG',
#       'name': 'Alison Krauss',
#       'type': 'artist',
#       'uri': 'spotify:artist:5J6L7N6B4nI1M5cwa29mQG'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/32y7QMTFfQC3ZZB3rb2RFs'},
#     'href': 'https://api.spotify.com/v1/albums/32y7QMTFfQC3ZZB3rb2RFs',
#     'id': '32y7QMTFfQC3ZZB3rb2RFs',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27392398ed354b6a223d60bf516',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0292398ed354b6a223d60bf516',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485192398ed354b6a223d60bf516',
#       'width': 64}],
#     'name': "Now That I've Found You: A Collection",
#     'release_date': '1995-01-01',
#     'release_date_precision': 'day',
#     'total_tracks': 12,
#     'type': 'album',
#     'uri': 'spotify:album:32y7QMTFfQC3ZZB3rb2RFs'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0OTnx2X2FDXeewcm72lavT'},
#      'href': 'https://api.spotify.com/v1/artists/0OTnx2X2FDXeewcm72lavT',
#      'id': '0OTnx2X2FDXeewcm72lavT',
#      'name': 'Alison Krauss & Union Station',
#      'type': 'artist',
#      'uri': 'spotify:artist:0OTnx2X2FDXeewcm72lavT'}],
#    'disc_number': 1,
#    'duration_ms': 260800,
#    'episode': False,
# ...
#    'duration_ms': 204186,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'US58E1400417'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/4whYDpJ5XVQpmvecbEHP5Q'},
#    'href': 'https://api.spotify.com/v1/tracks/4whYDpJ5XVQpmvecbEHP5Q',
#    'id': '4whYDpJ5XVQpmvecbEHP5Q',
#    'is_local': False,
#    'is_playable': True,
#    'name': "Where It's At",
#    'popularity': 61,
#    'preview_url': 'https://p.scdn.co/mp3-preview/d5ea3e563c5cfde3219e2b7d4ecbf68249f80055?cid=48288ce6ec40441ab533827580f710b0',
#    'track': True,
#    'track_number': 5,
#    'type': 'track',
#    'uri': 'spotify:track:4whYDpJ5XVQpmvecbEHP5Q'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2019-05-20T17:35:25Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/maddyburk'},
#    'href': 'https://api.spotify.com/v1/users/maddyburk',
#    'id': 'maddyburk',
#    'type': 'user',
#    'uri': 'spotify:user:maddyburk'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Sb8EHpZvyjSTT5KD9DjUZ'},
#       'href': 'https://api.spotify.com/v1/artists/6Sb8EHpZvyjSTT5KD9DjUZ',
#       'id': '6Sb8EHpZvyjSTT5KD9DjUZ',
#       'name': 'Ronnie Milsap',
#       'type': 'artist',
#       'uri': 'spotify:artist:6Sb8EHpZvyjSTT5KD9DjUZ'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4WQmzwrNO6bk1P6J0szhq5'},
#     'href': 'https://api.spotify.com/v1/albums/4WQmzwrNO6bk1P6J0szhq5',
#     'id': '4WQmzwrNO6bk1P6J0szhq5',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27332feb9998160662834ddbf04',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0232feb9998160662834ddbf04',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485132feb9998160662834ddbf04',
#       'width': 64}],
#     'name': 'Sings His Best Hits For Capitol Records',
#     'release_date': '1996-09-17',
#     'release_date_precision': 'day',
#     'total_tracks': 10,
#     'type': 'album',
#     'uri': 'spotify:album:4WQmzwrNO6bk1P6J0szhq5'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6Sb8EHpZvyjSTT5KD9DjUZ'},
#      'href': 'https://api.spotify.com/v1/artists/6Sb8EHpZvyjSTT5KD9DjUZ',
#      'id': '6Sb8EHpZvyjSTT5KD9DjUZ',
#      'name': 'Ronnie Milsap',
#      'type': 'artist',
#      'uri': 'spotify:artist:6Sb8EHpZvyjSTT5KD9DjUZ'}],
#    'disc_number': 1,
#    'duration_ms': 253360,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USCN19400119'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3byhGb1jyYOj8uNhA1UXoO'},
#    'href': 'https://api.spotify.com/v1/tracks/3byhGb1jyYOj8uNhA1UXoO',
#    'id': '3byhGb1jyYOj8uNhA1UXoO',
#    'is_local': False,
#    'is_playable': True,
#    'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/0YOVFzGazR21xDobJvGkxx'},
#     'href': 'https://api.spotify.com/v1/tracks/0YOVFzGazR21xDobJvGkxx',
#     'id': '0YOVFzGazR21xDobJvGkxx',
#     'type': 'track',
#     'uri': 'spotify:track:0YOVFzGazR21xDobJvGkxx'},
#    'name': 'Stranger In My House',
#    'popularity': 50,
#    'preview_url': None,
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:3byhGb1jyYOj8uNhA1UXoO'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2019-05-20T17:35:36Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/maddyburk'},
#    'href': 'https://api.spotify.com/v1/users/maddyburk',
#    'id': 'maddyburk',
#    'type': 'user',
#    'uri': 'spotify:user:maddyburk'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0hYxQe3AK5jBPCr5MumLHD'},
#       'href': 'https://api.spotify.com/v1/artists/0hYxQe3AK5jBPCr5MumLHD',
#       'id': '0hYxQe3AK5jBPCr5MumLHD',
#       'name': 'Sugarland',
#       'type': 'artist',
#       'uri': 'spotify:artist:0hYxQe3AK5jBPCr5MumLHD'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/401WMwWdvxHPnOKintiB0m'},
#     'href': 'https://api.spotify.com/v1/albums/401WMwWdvxHPnOKintiB0m',
#     'id': '401WMwWdvxHPnOKintiB0m',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273bf1212c8ea603d620fd49512',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02bf1212c8ea603d620fd49512',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851bf1212c8ea603d620fd49512',
#       'width': 64}],
#     'name': 'Enjoy The Ride',
#     'release_date': '2006-01-01',
#     'release_date_precision': 'day',
#     'total_tracks': 10,
#     'type': 'album',
#     'uri': 'spotify:album:401WMwWdvxHPnOKintiB0m'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0hYxQe3AK5jBPCr5MumLHD'},
#      'href': 'https://api.spotify.com/v1/artists/0hYxQe3AK5jBPCr5MumLHD',
#      'id': '0hYxQe3AK5jBPCr5MumLHD',
#      'name': 'Sugarland',
#      'type': 'artist',
#      'uri': 'spotify:artist:0hYxQe3AK5jBPCr5MumLHD'}],
#    'disc_number': 1,
#    'duration_ms': 207066,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUM70610457'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2TFy9ApipAVliib16vwWTc'},
#    'href': 'https://api.spotify.com/v1/tracks/2TFy9ApipAVliib16vwWTc',
#    'id': '2TFy9ApipAVliib16vwWTc',
#    'is_local': False,
#    'is_playable': True,
#    'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/63fKCxwRWqvp2Z6HQ6MHXU'},
#     'href': 'https://api.spotify.com/v1/tracks/63fKCxwRWqvp2Z6HQ6MHXU',
#     'id': '63fKCxwRWqvp2Z6HQ6MHXU',
#     'type': 'track',
#     'uri': 'spotify:track:63fKCxwRWqvp2Z6HQ6MHXU'},
#    'name': "Settlin'",
#    'popularity': 29,
#    'preview_url': None,
#    'track': True,
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:2TFy9ApipAVliib16vwWTc'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2019-05-20T17:35:48Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/maddyburk'},
#    'href': 'https://api.spotify.com/v1/users/maddyburk',
#    'id': 'maddyburk',
#    'type': 'user',
#    'uri': 'spotify:user:maddyburk'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6rJqqRce0Kvo2dJUXoHleC'},
#       'href': 'https://api.spotify.com/v1/artists/6rJqqRce0Kvo2dJUXoHleC',
#       'id': '6rJqqRce0Kvo2dJUXoHleC',
#       'name': 'Alabama',
#       'type': 'artist',
#       'uri': 'spotify:artist:6rJqqRce0Kvo2dJUXoHleC'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4oFLKch6Zh0YanY9Uj2s8z'},
#     'href': 'https://api.spotify.com/v1/albums/4oFLKch6Zh0YanY9Uj2s8z',
#     'id': '4oFLKch6Zh0YanY9Uj2s8z',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27348d7076be8ca3d2ec5e688d8',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0248d7076be8ca3d2ec5e688d8',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485148d7076be8ca3d2ec5e688d8',
#       'width': 64}],
#     'name': 'Ultimate Alabama 20 # 1 Hits',
#     'release_date': '2004-10-08',
#     'release_date_precision': 'day',
#     'total_tracks': 20,
#     'type': 'album',
#     'uri': 'spotify:album:4oFLKch6Zh0YanY9Uj2s8z'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6rJqqRce0Kvo2dJUXoHleC'},
#      'href': 'https://api.spotify.com/v1/artists/6rJqqRce0Kvo2dJUXoHleC',
#      'id': '6rJqqRce0Kvo2dJUXoHleC',
#      'name': 'Alabama',
#      'type': 'artist',
#      'uri': 'spotify:artist:6rJqqRce0Kvo2dJUXoHleC'}],
#    'disc_number': 1,
#    'duration_ms': 183120,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USRN19400223'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3onPZQxZ9igu7plus3rK7D'},
#    'href': 'https://api.spotify.com/v1/tracks/3onPZQxZ9igu7plus3rK7D',
#    'id': '3onPZQxZ9igu7plus3rK7D',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Tennessee River',
#    'popularity': 48,
#    'preview_url': 'https://p.scdn.co/mp3-preview/286513267fbcc675e7c5b783dd893389cdec0590?cid=48288ce6ec40441ab533827580f710b0',
#    'track': True,
#    'track_number': 8,
#    'type': 'track',
#    'uri': 'spotify:track:3onPZQxZ9igu7plus3rK7D'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2019-05-20T17:35:58Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/maddyburk'},
#    'href': 'https://api.spotify.com/v1/users/maddyburk',
#    'id': 'maddyburk',
#    'type': 'user',
#    'uri': 'spotify:user:maddyburk'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2IvkS5MXK0vPGnwyJsrEyV'},
#       'href': 'https://api.spotify.com/v1/artists/2IvkS5MXK0vPGnwyJsrEyV',
#       'id': '2IvkS5MXK0vPGnwyJsrEyV',
#       'name': 'Eric Church',
#       'type': 'artist',
#       'uri': 'spotify:artist:2IvkS5MXK0vPGnwyJsrEyV'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/37iovsHz9HV9PPR2DLbNnC'},
#     'href': 'https://api.spotify.com/v1/albums/37iovsHz9HV9PPR2DLbNnC',
#     'id': '37iovsHz9HV9PPR2DLbNnC',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273856dbe4f7e0fbb71e6a4d949',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02856dbe4f7e0fbb71e6a4d949',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851856dbe4f7e0fbb71e6a4d949',
#       'width': 64}],
#     'name': 'Carolina',
#     'release_date': '2009-01-01',
#     'release_date_precision': 'day',
#     'total_tracks': 13,
#     'type': 'album',
#     'uri': 'spotify:album:37iovsHz9HV9PPR2DLbNnC'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2IvkS5MXK0vPGnwyJsrEyV'},
#      'href': 'https://api.spotify.com/v1/artists/2IvkS5MXK0vPGnwyJsrEyV',
#      'id': '2IvkS5MXK0vPGnwyJsrEyV',
#      'name': 'Eric Church',
#      'type': 'artist',
#      'uri': 'spotify:artist:2IvkS5MXK0vPGnwyJsrEyV'}],
#    'disc_number': 1,
#    'duration_ms': 191333,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USCN10900014'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1ESipSqVefdknPg5IBKFND'},
#    'href': 'https://api.spotify.com/v1/tracks/1ESipSqVefdknPg5IBKFND',
#    'id': '1ESipSqVefdknPg5IBKFND',
#    'is_local': False,
#    'is_playable': True,
#    'linked_from': {'external_urls': {'spotify': 'https://open.spotify.com/track/2uZhNjlUQ9mnt0rS7hcAgF'},
#     'href': 'https://api.spotify.com/v1/tracks/2uZhNjlUQ9mnt0rS7hcAgF',
#     'id': '2uZhNjlUQ9mnt0rS7hcAgF',
#     'type': 'track',
#     'uri': 'spotify:track:2uZhNjlUQ9mnt0rS7hcAgF'},
#    'name': 'Smoke A Little Smoke',
#    'popularity': 67,
#    'preview_url': None,
#    'track': True,
#    'track_number': 7,
#    'type': 'track',
#    'uri': 'spotify:track:1ESipSqVefdknPg5IBKFND'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2019-05-20T17:36:11Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/maddyburk'},
#    'href': 'https://api.spotify.com/v1/users/maddyburk',
#    'id': 'maddyburk',
#    'type': 'user',
#    'uri': 'spotify:user:maddyburk'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3XnO697XIus1M0cMuxZjos'},
#       'href': 'https://api.spotify.com/v1/artists/3XnO697XIus1M0cMuxZjos',
#       'id': '3XnO697XIus1M0cMuxZjos',
#       'name': 'The Oak Ridge Boys',
#       'type': 'artist',
#       'uri': 'spotify:artist:3XnO697XIus1M0cMuxZjos'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/6aQEjw5vvwJaBxYY0w6HJI'},
#     'href': 'https://api.spotify.com/v1/albums/6aQEjw5vvwJaBxYY0w6HJI',
#     'id': '6aQEjw5vvwJaBxYY0w6HJI',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2738b3120b6fb17b2694da8d121',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e028b3120b6fb17b2694da8d121',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048518b3120b6fb17b2694da8d121',
#       'width': 64}],
#     'name': 'Oak Ridge Boys Collection',
#     'release_date': '1992-01-01',
#     'release_date_precision': 'day',
#     'total_tracks': 14,
#     'type': 'album',
#     'uri': 'spotify:album:6aQEjw5vvwJaBxYY0w6HJI'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3XnO697XIus1M0cMuxZjos'},
#      'href': 'https://api.spotify.com/v1/artists/3XnO697XIus1M0cMuxZjos',
#      'id': '3XnO697XIus1M0cMuxZjos',
#      'name': 'The Oak Ridge Boys',
#      'type': 'artist',
#      'uri': 'spotify:artist:3XnO697XIus1M0cMuxZjos'}],
#    'disc_number': 1,
#    'duration_ms': 159866,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USMC18213495'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1wtcyTExLF8nZu9ZphHIl1'},
#    'href': 'https://api.spotify.com/v1/tracks/1wtcyTExLF8nZu9ZphHIl1',
#    'id': '1wtcyTExLF8nZu9ZphHIl1',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'American Made',
#    'popularity': 54,
#    'preview_url': None,
#    'track': True,
#    'track_number': 9,
#    'type': 'track',
#    'uri': 'spotify:track:1wtcyTExLF8nZu9ZphHIl1'},
#   'video_thumbnail': {'url': None}},
#  {'added_at': '2019-05-20T19:05:46Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/maddyburk'},
#    'href': 'https://api.spotify.com/v1/users/maddyburk',
#    'id': 'maddyburk',
#    'type': 'user',
#    'uri': 'spotify:user:maddyburk'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4aJTB79uwT4sP0Nb8QGWHc'},
#       'href': 'https://api.spotify.com/v1/artists/4aJTB79uwT4sP0Nb8QGWHc',
#       'id': '4aJTB79uwT4sP0Nb8QGWHc',
#       'name': 'Joe Nichols',
#       'type': 'artist',
#       'uri': 'spotify:artist:4aJTB79uwT4sP0Nb8QGWHc'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3ndeTWIxrcj255qz36RSpb'},
#     'href': 'https://api.spotify.com/v1/albums/3ndeTWIxrcj255qz36RSpb',
#     'id': '3ndeTWIxrcj255qz36RSpb',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273a6449770ec54aedae61b4fd6',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02a6449770ec54aedae61b4fd6',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851a6449770ec54aedae61b4fd6',
#       'width': 64}],
#     'name': 'Revelation',
#     'release_date': '2004-01-01',
#     'release_date_precision': 'day',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:3ndeTWIxrcj255qz36RSpb'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4aJTB79uwT4sP0Nb8QGWHc'},
#      'href': 'https://api.spotify.com/v1/artists/4aJTB79uwT4sP0Nb8QGWHc',
#      'id': '4aJTB79uwT4sP0Nb8QGWHc',
#      'name': 'Joe Nichols',
#      'type': 'artist',
#      'uri': 'spotify:artist:4aJTB79uwT4sP0Nb8QGWHc'}],
#    'disc_number': 1,
#    'duration_ms': 235066,
#    'episode': False,
#    'explicit': False,
#    'external_ids': {'isrc': 'USUS70400004'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/28NvPQZ8XVVlV2eGmUw2Za'},
#    'href': 'https://api.spotify.com/v1/tracks/28NvPQZ8XVVlV2eGmUw2Za',
#    'id': '28NvPQZ8XVVlV2eGmUw2Za',
#    'is_local': False,
#    'is_playable': False,
#    'name': 'If Nobody Believed In You',
#    'popularity': 35,
#    'preview_url': None,
#    'restrictions': {'reason': 'market'},
#    'track': True,
#    'track_number': 6,
#    'type': 'track',
#    'uri': 'spotify:track:28NvPQZ8XVVlV2eGmUw2Za'},
#   'video_thumbnail': {'url': None}}]

# %%
for i in range(0, len(tracks_country)):
    track.append(tracks_country[i]['track']['name'])

# %%
track
# Out:
# ['Crazy - Single Version',
#  'Folsom Prison Blues',
#  'I Will Always Love You',
#  'Springsteen',
#  'He Stopped Loving Her Today',
#  'The Devil Went Down to Georgia',
#  'King Of The Road',
#  'Dirt Road Anthem',
#  'El Paso',
#  'I Fall To Pieces - Single Version',
#  'On the Road Again',
#  'Mountain Music',
#  'How Forever Feels',
#  'Stand By Your Man',
#  "Livin' On Love",
#  'Ring of Fire',
#  'Live Like You Were Dying',
#  "Your Cheatin' Heart",
#  'When You Say Nothing At All',
#  'Drink In My Hand',
#  'Luckenbach, Texas (Back to the Basics of Love)',
#  'Play It Again',
#  'God Bless The USA',
#  "Hello Darlin'",
#  'Cruise',
#  "Lookin' for Love",
#  "Pickin' up Strangers",
#  'Dreams Die Hard',
#  'Down and Dirty',
#  'Fool for Love',
#  'One in a Million',
#  'Anni',
#  'Do You Love as Good as You Look',
#  'Too Damned Old',
#  'Prisoner of Hope',
#  "Coal Miner's Daughter - Single Version",
#  "It's A Great Day To Be Alive",
#  'Take This Job and Shove It',
#  'Forever and Ever, Amen',
#  'Okie From Muskogee - Re-Recorded',
#  "Don't Take The Girl",
#  'Neon Moon - with Kacey Musgraves',
#  'Big Green Tractor',
#  'The Gambler',
#  "It's Five O'Clock Somewhere",
#  'A Boy Named Sue - Live at San Quentin State Prison, San Quentin, CA - February 1969',
#  "Don't Blink",
#  "All My Ex's Live In Texas",
#  'Wagon Wheel',
#  "Kiss An Angel Good Mornin'",
#  'Colder Weather',
#  'Good Hearted Woman',
#  'Fancy',
#  "Hey, Good Lookin'",
#  'Cowboy Take Me Away',
#  'Six Days on the Road',
#  "It's Your Love",
#  'You Never Even Called Me By My Name',
#  'Tim McGraw',
#  'Sunday Morning Coming Down - Live at Ryman Auditorium, Nashville, TN - July 1970',
#  'Islands In the Stream',
#  'Crazy Girl',
#  'Always on My Mind',
#  'Chicken Fried',
#  "Walkin' After Midnight",
#  'My Maria - with Thomas Rhett',
#  'Alright',
#  "Mammas, Don't Let Your Babies Grow Up to Be Cowboys",
#  'If Tomorrow Never Comes',
#  'Need You Now',
#  'Daddy Sang Bass',
#  'Landslide',
#  '9 to 5',
#  'The Battle Of New Orleans',
#  'God Gave Me You',
#  'Gentle On My Mind - Remastered 2001',
#  'The Night The Lights Went Out In Georgia',
#  'Jambalaya (On The Bayou)',
#  'Mud On the Tires',
#  'Independence Day',
#  "The Fightin' Side Of Me",
#  "Should've Been A Cowboy",
#  'I Walk the Line',
#  "Drivin' My Life Away",
#  "Gettin' You Home",
#  'Hello Walls',
#  'Margaritaville',
#  'Drink A Beer',
#  'Tulsa Time',
#  'Big Bad John',
#  "She Don't Know She's Beautiful",
#  'Drunk On A Plane',
#  'Louisiana Woman, Mississippi Man',
#  'Smoky Mountain Rain',
#  'Dang Me',
#  'Something Like That',
#  'Is Anybody Going To San Antone (feat. Charley Pride)',
#  'Let Your Love Flow',
#  'Sixteen Tons',
#  "She Thinks My Tractor's Sexy",
#  "I'm So Lonesome I Could Cry",
#  "If You're Gonna Play in Texas (You Gotta Have a Fiddle in the Band)",
#  'Honey Bee',
#  'Blue Eyes Crying In the Rain',
#  'Amazed',
#  "I'm Comin' Over",
#  "I've Got A Tiger By The Tail - 2006 Remastered Version",
#  'Angel Of The Morning',
#  'Ode To Billie Joe',
#  'Young',
#  'Crazy',
#  'Chug-A-Lug',
#  'Meet In the Middle',
#  'I Love',
#  'Watching Airplanes',
#  'Sweet Dreams (Of You) - Single Version',
#  'I Cross My Heart - Pure Country Soundtrack Version',
#  'Tennessee Flat-Top Box',
#  'Good Directions',
#  "She's In Love With The Boy",
#  'Cold, Cold Heart',
#  'Remind Me (with Carrie Underwood)',
#  "She's All I Got",
#  'Lady',
#  "You Ain't Woman Enough",
#  'Take A Back Road',
#  'Last Date - Remastered',
#  'Desperado - (Live)',
#  'Highwayman',
#  "That's What I Love About Sunday",
#  'Amarillo By Morning',
#  'Devil Woman',
#  "Don't Think I Don't Think About It",
#  'Rose Garden',
#  'Little Bitty',
#  'Help Me Make It Through The Night',
#  "Nineteen Somethin'",
#  'The Race Is On',
#  'Flowers On the Wall',
#  'I Can Love You Like That',
#  'Walk on By',
#  'What Hurts The Most',
#  'Jackson',
#  'I Love a Rainy Night',
#  'Oh Lonesome Me',
#  "Just Got Started Lovin' You",
#  'The Most Beautiful Girl',
#  "Fishin' in the Dark",
#  'D-I-V-O-R-C-E',
#  'Suds in the Bucket',
#  'Mama Tried',
#  "Wish I Didn't Know Now",
#  "Don't Happen Twice",
#  'My Heroes Have Always Been Cowboys - Live',
#  'Where The Green Grass Grows',
#  'Act Naturally',
#  "It Won't Be Like This For Long",
#  'Queen Of Hearts',
#  'Make the World Go Away',
#  'Stay',
#  'Daydreams About Night Things',
#  'Delta Dawn',
#  'Ocean Front Property',
#  'Big Iron',
#  'Are You Gonna Kiss Me Or Not',
#  "If You've Got The Money I've Got the Time",
#  'Chattahoochee',
#  "Don't Come Home A-Drinkin' (With Lovin' On Your Mind)",
#  'I Swear',
#  'What Kinda Gone',
#  'Lucille',
#  'Heads Carolina, Tails California',
#  'North to Alaska',
#  'Toes',
#  'Wings of a Dove',
#  'Wings Of A Dove',
#  "I Wouldn't Have Missed It For The World",
#  '(Ghost) Riders in the Sky',
#  'I Go Back',
#  'Maybe It Was Memphis',
#  'Linda on My Mind',
#  'If I Die Young',
#  'Pop a Top',
#  'Deeper Than the Holler',
#  'We Danced',
#  "You're Lookin' At Country",
#  "Don't Rock the Jukebox",
#  "Who Wouldn't Wanna Be Me",
#  'Heartaches by the Numbers - Rerecorded',
#  'The House That Built Me',
#  "She's Not the Cheatin' Kind",
#  'England Swings',
#  'There Goes My Life',
#  'One Piece at a Time',
#  "I Was Country When Country Wasn't Cool - Live At The Roy Acuff Theater Nashville, TN, 1981",
#  "I'm a Ramblin' Man",
#  'Rain Is A Good Thing',
#  'Wasted Days and Wasted Nights',
#  'Wanted',
#  'I Love the Way You Love Me',
#  'Daytime Friends',
#  'All-American Girl',
#  'You And I',
#  "Don't You Wanna Stay (with Kelly Clarkson)",
#  'The End of the World',
#  'Song of the South',
#  'American Kids',
#  'The Girl On The Billboard',
#  'Breathe',
#  'Behind Closed Doors',
#  'Elvira',
#  'Love Me Like You Mean It',
#  'Working Man Blues',
#  'The Three Bells',
#  'She Believes In Me',
#  "You're Gonna Miss This",
#  'Detroit City',
#  "Who's That Man",
#  "I Can't Help It (If I'm Still In Love With You) - Single Version",
#  'Yeah',
#  "(I'm A) Stand by My Woman Man",
#  'Beer In Mexico',
#  "He'll Have to Go",
#  'Love Like Crazy',
#  'Pancho and Lefty',
#  'The Closer You Get',
#  'Why Ya Wanna',
#  'Galveston - Remastered 2001',
#  'Two Dozen Roses',
#  'Your Man',
#  "I've Been Everywhere",
#  "Must Be Doin' Somethin' Right",
#  'Golden Ring',
#  'All My Rowdy Friends (Have Settled Down)',
#  'Somebody Like You',
#  "I Can't Stop Loving You",
#  'Crash My Party',
#  "She's Got You - Single Version",
#  'Just To See You Smile',
#  'Amanda',
#  'Even If It Breaks Your Heart',
#  'Abilene',
#  'This Kiss',
#  'Bottoms Up',
#  'A Better Man',
#  'Why Me',
#  "What Was I Thinkin'",
#  "I Think I'll Just Stay Here And Drink",
#  'The Chair',
#  "She's Everything",
#  "Please Help Me, I'm Falling",
#  'Slow Hand',
#  'City of New Orleans',
#  'Tattoos on This Town',
#  "Life's a Dance",
#  'Singing the Blues',
#  'These Are My People',
#  'Wolverton Mountain',
#  "Who's Cheatin' Who",
#  "You'e the Reason God Made Oklahoma",
#  'Drunk On You',
#  'Down at the Twist and Shout',
#  "Only Daddy That'll Walk the Line",
#  'Tequila Makes Her Clothes Fall Off',
#  'Old Dogs, Children And Watermelon Wine',
#  'Sold (The Grundy County Auction Incident)',
#  "As She's Walking Away (feat. Alan Jackson)",
#  'Honky Tonk Blues',
#  'Just A Kiss',
#  'Whiskey River',
#  'Brand New Man - with Luke Combs',
#  'For the Good Times',
#  "I Got A Feelin'",
#  'Satin Sheets',
#  "Don't Ya",
#  'Through The Years - Single Version',
#  "I Don't Wanna Play House",
#  'Austin',
#  'Anymore',
#  'Two Dollars in the Jukebox',
#  'Nothing On But The Radio',
#  'Strawberry Wine',
#  'White Lightning - Single Version',
#  "She's Got You",
#  'On the Other Hand',
#  'I Got the Boy',
#  'Straight Tequila Night',
#  'Are You Sure Hank Done It This Way',
#  'Gimmie That Girl',
#  'Any Man Of Mine',
#  'Green Green Grass Of Home',
#  'Leave The Night On',
#  "Tryin' To Get Over You",
#  'Dust On The Bottle',
#  "Why Don't We Just Dance",
#  'Together Again - 2006 Remastered Version',
#  'Walkaway Joe',
#  'Ten Rounds with Jose Cuervo - Recall Mix',
#  'Coat of Many Colors',
#  'The Good Stuff',
#  "I Can't Stop Loving You",
#  'A Country Boy Can Survive',
#  'Country Girl (Shake It For Me)',
#  'Do You Know You Are My Sunshine?',
#  "Grandpa (Tell Me 'Bout The Good Old Days)",
#  'Real Good Man',
#  'She Thinks I Still Care',
#  'All My Friends Say',
#  'Except for Monday',
#  'There Goes My Everything',
#  'Remember When',
#  "We've Got Tonight",
#  "Don't Take Your Guns to Town",
#  'Save It for a Rainy Day',
#  "I've Always Been Crazy",
#  "Don't Close Your Eyes",
#  'Watching You',
#  "You're Still The One",
#  'Amarillo Sky',
#  'Georgia On My Mind',
#  "It's A Little Too Late",
#  "Runnin' Outta Moonlight",
#  'Big City',
#  'You Look So Good In Love',
#  'Every Storm (Runs Out Of Rain)',
#  "I'm the Only Hell (Mama Ever Raised)",
#  'Wild One',
#  'Knee Deep (feat. Jimmy Buffett)',
#  'Texas (When I Die)',
#  'Free And Easy (Down The Road I Go)',
#  'God Blessed Texas',
#  'Baby Girl - 2nd Version/Remix/Album Version',
#  "I'll Go To My Grave Loving You",
#  'Please Remember Me',
#  'Where I Come From',
#  "Ain't Worth the Whiskey",
#  'Some Broken Hearts Never Mend',
#  'Give It Away',
#  "I'm Already There",
#  "Ruby Don't Take Your Love To Town",
#  'Every Light In The House',
#  'Whatever It Is',
#  'Country Must Be Country Wide',
#  '500 Miles Away from Home',
#  'Whose Bed Have Your Boots Been Under?',
#  'Sideways',
#  'Silver Wings',
#  'Barefoot Blue Jean Night',
#  'Guitars, Cadillacs',
#  'Where I Come From',
#  'Before the Next Teardrop Falls',
#  "She's Country",
#  'Rose Colored Glasses',
#  'Small Town Saturday Night',
#  'In Color',
#  'Mercury Blues',
#  'Someone Else Calling You Baby',
#  'No One Else On Earth',
#  'Bob Wills Is Still the King',
#  'No Shoes, No Shirt, No Problems',
#  'Coward Of The County',
#  'Wasted',
#  'Love in the First Degree',
#  'Alcohol',
#  'Lynda',
#  'Gone Country',
#  'Voices',
#  'Today I Started Loving You Again - Remastered',
#  'When She Cries',
#  'Bless The Broken Road',
#  'Walking The Floor Over You',
#  'Do I',
#  'Be My Baby Tonight',
#  'My Kinda Party',
#  'Wine Me Up',
#  "Killin' Time",
#  "You'll Think Of Me - Single Version",
#  'Blue Skies',
#  "Ain't Nothing 'Bout You - with Brett Young",
#  'The Race Is On',
#  'Set "Em Up Joe',
#  'Walking In Memphis',
#  'Indian Outlaw',
#  'Our Song',
#  'Fist City',
#  'When She Says Baby',
#  'Louisiana Saturday Night',
#  'Big Star',
#  'Marie Laveau',
#  'My Town',
#  'Seven Year Ache',
#  'Mayberry',
#  "Your Good Girl's Gonna Go Bad",
#  'Downtown',
#  "Long-Legged Guitar Pickin' Man (with June Carter Cash) - Live at Annex 14 NCO Club, Long Binh, Vietnam, January 1969",
#  'Born Country',
#  'You',
#  "I'm Gonna Hire A Wino To Decorate Our Home",
#  'Get Me Some Of That',
#  'Here You Come Again',
#  'You Decorated My Life',
#  'Before He Cheats',
#  "Love's Gonna Live Here",
#  "Ol' Red",
#  'The Bottle Let Me Down',
#  'Come Over',
#  'Love Bug',
#  'Crazy Little Thing Called Love - 2002 Remaster',
#  "Farmer's Daughter",
#  "I'm Movin' On",
#  "Mama's Broken Heart",
#  'I Like It, I Love It',
#  "That's My Job",
#  'I Run To You',
#  "One's On The Way",
#  'Aw Naw',
#  'I Told You So - feat. Randy Travis',
#  'How Country Feels',
#  'Country Sunshine',
#  'Red Dirt Road - with Cody Johnson',
#  'One More Last Chance',
#  'I Like Beer',
#  "Somethin' 'Bout A Truck",
#  'Homegrown',
#  'Down On The Farm',
#  "That's the Way Love Goes",
#  'Beautiful Mess',
#  'Some Girls Do',
#  "Don't The Girls All Get Prettier At Closing Time",
#  'Pontoon',
#  'Love, Me',
#  'Would You Go With Me',
#  "If You've Got the Money I've Got the Time",
#  'Tall, Tall Trees',
#  'Ticks',
#  'Skip a Rope',
#  'Time Marches On',
#  'My Next Thirty Years',
#  "Don't It Make My Brown Eyes Blue",
#  'Pickup Man',
#  "I Don't Want This Night To End",
#  'Faster Horses (The Cowboy And The Poet)',
#  'I Drive Your Truck',
#  'Carrying Your Love With Me',
#  'Why Does It Have to Be (Wrong or Right)',
#  'Summertime',
#  'Backside of Thirty',
#  'Over You',
#  'Take Me Down',
#  'These Days',
#  'Move It On Over',
#  'I Believe In You',
#  'I Loved Her First',
#  'Jolene',
#  'This Is Country Music',
#  'Blame It on Your Heart',
#  'Fly over States',
#  'Help Me Make It Through the Night',
#  'American Honey',
#  'Could I Have This Dance',
#  'Til My Last Day',
#  'Silver Threads and Golden Needles',
#  'Talladega',
#  'A Thousand Miles from Nowhere',
#  'Pure Love',
#  'Some Beach',
#  'Coca Cola Cowboy',
#  'Wild Angels',
#  'Never Wanted Nothing More',
#  'El Paso City',
#  "That Ain't No Way To Go",
#  'Write This Down',
#  'This Is How We Roll',
#  "I'm Just an Old Chunk of Coal (But I'm Gonna Be a Diamond Some Day)",
#  'I Can Take It From There',
#  'She Got the Goldmine (I Got the Shaft)',
#  'Come Back Song',
#  "(If You're Not In It For Love) I'm Outta Here!",
#  'Rainy Day Woman',
#  'Bartender',
#  "She's Acting Single (I'm Drinking Doubles)",
#  "XXX's And OOO's (An American Girl)",
#  'Picture (feat. Sheryl Crow)',
#  'Old Alabama (feat. Alabama)',
#  'Wide Open Spaces',
#  'Crash and Burn',
#  'Highway 20 Ride',
#  "You've Never Been This Far Before - Re-recorded",
#  'T-R-O-U-B-L-E',
#  'Hey Girl',
#  'The Bluest Eyes In Texas',
#  'Undo It',
#  'Something More',
#  'The Year That Clayton Delaney Died',
#  'Wink',
#  'When the Sun Goes Down',
#  'All The Gold In California',
#  'Who I Am',
#  "She's My Kind Of Rain",
#  'Angel Flying Too Close to the Ground',
#  'Third Rate Romance',
#  'Hell Yeah',
#  'Love Without End, Amen',
#  'Thanks A Lot',
#  "Why Didn't I Think Of That",
#  'Redneck Crazy',
#  'The Way You Love Me',
#  'Passionate Kisses',
#  'Courtesy Of The Red, White And Blue (The Angry American)',
#  'Would You Lay With Me',
#  'The One That Got Away',
#  'Blue',
#  'Easy Loving',
#  "Lot Of Leavin' Left To Do",
#  'Living in Fast Forward',
#  'Eighteen Wheels And A Dozen Roses',
#  'Better Life',
#  'All My Rowdy Friends Are Coming Over Tonight',
#  "Ramblin' Fever",
#  'It Goes Like This',
#  "Baby's Got Her Blue Jeans On",
#  "The Party's Over",
#  'The Keeper Of The Stars',
#  'Leave the Pieces',
#  'San Antonio Stroll - Single Version',
#  'Keep Me in Mind',
#  'My Baby Loves Me',
#  'Ladies Love Country Boys',
#  'Trashy Women',
#  'San Antonio Rose',
#  'I Love This Bar',
#  'My Best Friend',
#  'Ballad of a Teenage Queen',
#  'My Wish',
#  'Heartland - Pure Country/Soundtrack Version',
#  'All of Me',
#  "She's Got It All",
#  'A Little More Country Than That',
#  'Mind Your Own Business',
#  'Over',
#  'Nobody',
#  'A Little Bit Stronger',
#  "Bartender's Blues",
#  'Alibis - 2007 Remaster',
#  'Lady Lay Down',
#  'Redneck Yacht Club',
#  "Why'd You Come in Here Lookin' Like That",
#  'Waltz Across Texas',
#  'Every Mile A Memory',
#  "She Just Started Liking Cheatin' Songs",
#  'Sangria',
#  'Old Flame',
#  'Running Bear',
#  'Night Train',
#  "It's Such A Pretty World Today",
#  'Honky Tonk Man',
#  'Out Last Night',
#  'Does He Love You',
#  'See You Tonight',
#  'Carried Away',
#  'Swinging Doors - Re-Recorded',
#  'Boondocks',
#  "I'm From The Country - Single Version",
#  "The Wurlitzer Prize (I Don't Want to Get Over You)",
#  'Anywhere With You',
#  'It Must Be Love',
#  'You and Tequila (feat. Grace Potter)',
#  'Man in Black',
#  'Prop Me Up Beside The Jukebox (If I Die)',
#  "There's A Honky Tonk Angel (Who'll Take Me Back In) - Single Version",
#  'Take a Little Ride',
#  "Don't Let Our Love Start Slippin' Away",
#  'I Need You',
#  'Saginaw Michigan',
#  "Here's a Quarter (Call Someone Who Cares)",
#  'Life is a Highway',
#  'Lost and Found - with Tyler Booth',
#  'All Over The Road',
#  'Seven Spanish Angels (with Ray Charles)',
#  'Fool Hearted Memory',
#  "Don't Forget to Remember Me",
#  'The One I Loved Back Then (The Corvette Song)',
#  'The Cowboy In Me',
#  'Yesterday When I Was Young',
#  "There's No Getting' Over Me",
#  'Little Moments',
#  "Forty Hour Week (For a Livin')",
#  "Don't",
#  'Crystal Chandeliers',
#  'Stand By Me - Single Version',
#  'Mean to Me',
#  "Boot Scootin' Boogie - with Midland",
#  'Last Name',
#  'Kick a Little',
#  'The Ride',
#  'Free',
#  'I Feel Lucky',
#  'Roll With It',
#  'Tennessee Whiskey',
#  'I Do (Cherish You)',
#  'The Truth',
#  'This Time',
#  '5-1-5-0',
#  'When I Said I Do',
#  'I Hope You Dance',
#  "Prayin' For Daylight",
#  "I Don't Want To Miss A Thing",
#  "It Wasn't God Who Made Honky Tonk Angels",
#  "I Don't Have To Be Me ('Til Monday) - Single Version",
#  'My Woman, My Woman, My Wife',
#  'I Can Still Make Cheyenne',
#  'Hard To Love',
#  'Is There Life Out There',
#  'Then',
#  'Slide off of Your Satin Sheets',
#  'Sleeping Single In A Double Bed - Single Version',
#  'Fast Cars And Freedom',
#  'In a Different Light',
#  "That's How Country Boys Roll",
#  "Still Doin' Time",
#  'We Just Disagree',
#  'Beat of the Music',
#  'Get Your Shine On',
#  "I Don't Even Know Your Name",
#  'Branded Man',
#  'Who I Am With You',
#  "That Don't Impress Me Much",
#  "Drinkin' Thing",
#  'Troubadour',
#  'It Was Me',
#  'Brothers Of The Highway',
#  'River Of Love',
#  'House Of Cash',
#  'I Saw God Today',
#  'Give Me More Time',
#  "When You're In Love",
#  'Make Her Fall In Love With Me Song',
#  'West Texas Town',
#  'House With No Doors',
#  'If Heartaches Were Horses',
#  'The Grand Tour',
#  'Holes In The Floor Of Heaven',
#  'Beer For My Horses',
#  "Mama He's Crazy",
#  'Reuben James',
#  'Save a Horse (Ride a Cowboy)',
#  'Everywhere',
#  'Sure Be Cool If You Did',
#  'Sing Me Back Home - Re-Recorded',
#  'Boots On',
#  'Fast as You',
#  "Boys 'Round Here (feat. Pistol Annies & Friends)",
#  "We're Gonna Hold On",
#  'Tomorrow',
#  'Just Another Day In Paradise',
#  'It Matters to Me',
#  'As Good As I Once Was',
#  'The Man That Turned My Mama On',
#  'Whiskey Lullaby (feat. Alison Krauss)',
#  'One Way Ticket (Because I Can)',
#  'Settle For A Slowdown',
#  'Tequila Sheila',
#  'Find out Who Your Friends Are',
#  'Little Rock',
#  'Sunshine & Whiskey',
#  'Why Baby Why',
#  'Roller Coaster',
#  'Watermelon Crawl',
#  "This Time I've Hurt Her More Than She Loves Me",
#  'Why',
#  'Poor, Poor Pitiful Me',
#  'Sweet Annie',
#  'Are the Good Times Really Over (I Wish a Buck Was Still Silver)',
#  'Hope You Get Lonely Tonight',
#  "Honey, I'm Home",
#  'How Do You Like Me Now?!',
#  'If I Could Make a Living',
#  'Rednecks, White Socks and Blue Ribbon Beer',
#  'Rock My World - Little Country Girl',
#  "Don't It",
#  'Amanda',
#  'Dixieland Delight - Single Edit',
#  "I'm Gonna Miss Her",
#  'Bye-Bye',
#  'Funny How Time Slips Away',
#  "Highway Don't Care",
#  "There's Your Trouble",
#  'Thank God and Greyhound',
#  'Neon Light',
#  'Two Black Cadillacs',
#  'Fourteen Carat Mind',
#  "When I Get Where I'm Going (feat. Dolly Parton)",
#  'Little Rock',
#  'Drink to That All Night',
#  'Understand Your Man',
#  "She Won't Be Lonely Long",
#  'If I Said You Had A Beautiful Body Would You Hold It Against Me',
#  'Live a Little',
#  "I'm in a Hurry (And Don't Know Why)",
#  "I Don't Dance",
#  "I'm No Stranger to the Rain",
#  'Just Someone I Used to Know',
#  'Mine Would Be You',
#  "Diggin' Up Bones",
#  "Honky Tonkin'",
#  'Good Morning Beautiful',
#  "Tight Fittin' Jeans",
#  'Lover, Lover',
#  'Daddy Frank (The Guitar Man)',
#  'Piece of My Heart',
#  'Honky Tonk Badonkadonk',
#  'Make Me Wanna',
#  "Who's Gonna Fill Their Shoes",
#  "Goin' Through The Big D",
#  'Goodnight Kiss',
#  'Lonely Eyes',
#  'Joshua',
#  'I Can Still Feel You',
#  'Let Me Down Easy',
#  'Lonely Women Make Good Lovers',
#  'Baby Blue',
#  'Does My Ring Hurt Your Finger',
#  'Stuck Like Glue',
#  'Wanted',
#  'Red Ragtop',
#  "What's Your Mama's Name Child",
#  "Daddy's Hands",
#  'Crying Time',
#  'Bubba Shot The Jukebox',
#  'Just a Dream',
#  'After The Fire Is Gone - Single Version',
#  'Whiskey Girl',
#  'Little Rain',
#  "Nothin' New Under The Neon",
#  "What I Can't Put Down",
#  'Why Not Me',
#  'Play Something Country',
#  'Do-Wacka-Do',
#  'Letter to Me',
#  "Lesson In Leavin'",
#  "Where It's At",
#  'Stranger In My House',
#  "Settlin'",
#  'Tennessee River',
#  'Smoke A Little Smoke',
#  'American Made',
#  'If Nobody Believed In You']

# %% [markdown]
# ### Getting artists

# %%
artist=[]

# %%
# extracting artists from track
def get_artists_from_track(track):
    return [artist["name"] for artist in track["artists"]]

# %%
# extracting artists from playlist
def get_artists_from_playlist(playlist_id):
    tracks_from_playlist = get_playlist_tracks("spotify", playlist_id)
    return list(get_artists_from_track(track["track"]) for track in tracks_from_playlist)

# %%
artists_country = get_artists_from_playlist("3RPaWvjgg1SAi8oIh09Irp")

# %%
artists_country
# Out:
# [['Patsy Cline', 'The Jordanaires'],
#  ['Johnny Cash', 'The Tennessee Two'],
#  ['Dolly Parton'],
#  ['Eric Church'],
#  ['George Jones'],
#  ['The Charlie Daniels Band'],
#  ['Roger Miller'],
#  ['Jason Aldean'],
#  ['Marty Robbins'],
#  ['Patsy Cline', 'The Jordanaires'],
#  ['Willie Nelson'],
#  ['Alabama'],
#  ['Kenny Chesney'],
#  ['Tammy Wynette'],
#  ['Alan Jackson'],
#  ['Johnny Cash'],
#  ['Tim McGraw'],
#  ['Hank Williams', 'Drifting Cowboys'],
#  ['Alison Krauss & Union Station'],
#  ['Eric Church'],
#  ['Waylon Jennings'],
#  ['Luke Bryan'],
#  ['Lee Greenwood'],
#  ['Conway Twitty'],
#  ['Florida Georgia Line'],
#  ['Johnny Lee'],
#  ['Johnny Lee'],
#  ['Johnny Lee'],
#  ['Johnny Lee'],
#  ['Johnny Lee'],
#  ['Johnny Lee'],
#  ['Johnny Lee'],
#  ['Johnny Lee'],
#  ['Johnny Lee'],
#  ['Johnny Lee'],
#  ['Loretta Lynn'],
#  ['Travis Tritt'],
#  ['Johnny Paycheck'],
#  ['Randy Travis'],
#  ['Merle Haggard'],
#  ['Tim McGraw'],
#  ['Brooks & Dunn', 'Kacey Musgraves'],
#  ['Jason Aldean'],
#  ['Kenny Rogers'],
#  ['Alan Jackson', 'Jimmy Buffett'],
#  ['Johnny Cash'],
#  ['Kenny Chesney'],
#  ['George Strait'],
#  ['Darius Rucker'],
#  ['Charley Pride'],
#  ['Zac Brown Band'],
#  ['Waylon Jennings', 'Willie Nelson'],
#  ['Reba McEntire'],
#  ['Hank Williams', 'Drifting Cowboys'],
#  ['The Chicks'],
#  ['Dave Dudley'],
#  ['Tim McGraw', 'Faith Hill'],
#  ['David Allan Coe'],
#  ['Taylor Swift'],
#  ['Johnny Cash'],
#  ['Dolly Parton', 'Kenny Rogers'],
#  ['Eli Young Band'],
#  ['Willie Nelson'],
#  ['Zac Brown Band'],
#  ['Patsy Cline'],
#  ['Brooks & Dunn', 'Thomas Rhett'],
#  ['Darius Rucker'],
#  ['Waylon Jennings', 'Willie Nelson'],
#  ['Kent Blazy & Garth Brooks'],
#  ['Lady A'],
#  ['Johnny Cash'],
#  ['The Chicks'],
#  ['Dolly Parton'],
#  ['Johnny Horton'],
#  ['Blake Shelton'],
#  ['Glen Campbell'],
#  ['Reba McEntire'],
#  ['Hank Williams', 'Drifting Cowboys'],
#  ['Brad Paisley'],
#  ['Martina McBride'],
#  ['Merle Haggard'],
#  ['Toby Keith'],
#  ['Johnny Cash'],
#  ['Eddie Rabbitt'],
#  ['Chris Young'],
#  ['Faron Young'],
#  ['Jimmy Buffett'],
#  ['Luke Bryan'],
#  ['Don Williams'],
#  ['Jimmy Dean'],
#  ['Sammy Kershaw'],
#  ['Dierks Bentley'],
#  ['Conway Twitty', 'Loretta Lynn'],
#  ['Ronnie Milsap'],
#  ['Roger Miller'],
#  ['Tim McGraw'],
#  ['Charley Pride'],
#  ['The Bellamy Brothers'],
#  ['Tennessee Ernie Ford'],
#  ['Kenny Chesney'],
#  ['Hank Williams'],
#  ['Alabama'],
#  ['Blake Shelton'],
#  ['Willie Nelson'],
#  ['Lonestar'],
#  ['Chris Young'],
#  ['Buck Owens'],
#  ['Juice Newton'],
#  ['Bobbie Gentry'],
#  ['Kenny Chesney'],
#  ['Linda Ronstadt'],
#  ['Roger Miller'],
#  ['Diamond Rio'],
#  ['Tom T. Hall'],
#  ['Gary Allan'],
#  ['Patsy Cline'],
#  ['George Strait'],
#  ['Johnny Cash'],
#  ['Billy Currington'],
#  ['Trisha Yearwood'],
#  ['Hank Williams', 'Drifting Cowboys'],
#  ['Brad Paisley', 'Carrie Underwood'],
#  ['Johnny Paycheck'],
#  ['Kenny Rogers'],
#  ['Loretta Lynn'],
#  ['Rodney Atkins'],
#  ['Floyd Cramer'],
#  ['Clint Black'],
#  ['The Highwaymen',
#   'Willie Nelson',
#   'Johnny Cash',
#   'Waylon Jennings',
#   'Kris Kristofferson'],
#  ['Craig Morgan'],
#  ['George Strait'],
#  ['Marty Robbins'],
#  ['Darius Rucker'],
#  ['Lynn Anderson'],
#  ['Alan Jackson'],
#  ['Sammi Smith'],
#  ['Mark Wills'],
#  ['George Jones'],
#  ['The Statler Brothers'],
#  ['John Michael Montgomery'],
#  ['Leroy Van Dyke'],
#  ['Rascal Flatts'],
#  ['Johnny Cash', 'June Carter Cash'],
#  ['Eddie Rabbitt'],
#  ['Don Gibson'],
#  ['James Otto'],
#  ['Charlie Rich'],
#  ['Nitty Gritty Dirt Band'],
#  ['Tammy Wynette'],
#  ['Sara Evans'],
#  ['Merle Haggard & The Strangers'],
#  ['Toby Keith'],
#  ['Kenny Chesney'],
#  ['Willie Nelson', 'Chris Stapleton'],
#  ['Tim McGraw'],
#  ['Buck Owens'],
#  ['Darius Rucker'],
#  ['Juice Newton'],
#  ['Eddy Arnold'],
#  ['Sugarland'],
#  ['Ronnie Milsap'],
#  ['Tanya Tucker'],
#  ['George Strait'],
#  ['Marty Robbins'],
#  ['Thompson Square'],
#  ['Willie Nelson'],
#  ['Alan Jackson'],
#  ['Loretta Lynn'],
#  ['John Michael Montgomery'],
#  ['Chris Cagle'],
#  ['Kenny Rogers'],
#  ['Jo Dee Messina'],
#  ['Johnny Horton'],
#  ['Zac Brown Band'],
#  ['Ferlin Husky', 'Hank Locklin'],
#  ['Dolly Parton', 'Tammy Wynette', 'Loretta Lynn'],
#  ['Ronnie Milsap'],
#  ['Johnny Cash'],
#  ['Kenny Chesney'],
#  ['Pam Tillis'],
#  ['Conway Twitty'],
#  ['The Band Perry'],
#  ['Jim Ed Brown'],
#  ['Randy Travis'],
#  ['Brad Paisley'],
#  ['Loretta Lynn'],
#  ['Alan Jackson'],
#  ['Keith Urban'],
#  ['Guy Mitchell'],
#  ['Miranda Lambert'],
#  ['Brooks & Dunn'],
#  ['Roger Miller'],
#  ['Kenny Chesney'],
#  ['Johnny Cash', 'Tennessee Three'],
#  ['Barbara Mandrell', 'George Jones'],
#  ['Waylon Jennings'],
#  ['Luke Bryan'],
#  ['Freddy Fender'],
#  ['Hunter Hayes'],
#  ['John Michael Montgomery'],
#  ['Kenny Rogers'],
#  ['Carrie Underwood'],
#  ['Eddie Rabbitt', 'Crystal Gayle'],
#  ['Jason Aldean', 'Kelly Clarkson'],
#  ['Skeeter Davis'],
#  ['Alabama'],
#  ['Kenny Chesney'],
#  ['Del Reeves'],
#  ['Faith Hill'],
#  ['Charlie Rich'],
#  ['The Oak Ridge Boys'],
#  ['Kelsea Ballerini'],
#  ['Merle Haggard'],
#  ['The Browns'],
#  ['Kenny Rogers'],
#  ['Trace Adkins'],
#  ['Bobby Bare'],
#  ['Toby Keith'],
#  ['Hank Williams', 'Drifting Cowboys'],
#  ['Joe Nichols'],
#  ['Ronnie Milsap'],
#  ['Kenny Chesney'],
#  ['Jim Reeves'],
#  ['Lee Brice'],
#  ['Willie Nelson', 'Merle Haggard'],
#  ['Alabama'],
#  ['Jana Kramer'],
#  ['Glen Campbell'],
#  ['Shenandoah'],
#  ['Josh Turner'],
#  ['Hank Snow'],
#  ['Billy Currington'],
#  ['George Jones', 'Tammy Wynette'],
#  ['Hank Williams, Jr.'],
#  ['Keith Urban'],
#  ['Ray Charles'],
#  ['Luke Bryan'],
#  ['Patsy Cline'],
#  ['Tim McGraw'],
#  ['Waylon Jennings'],
#  ['Eli Young Band'],
#  ['George Hamilton IV'],
#  ['Faith Hill'],
#  ['Brantley Gilbert'],
#  ['Clint Black'],
#  ['Kris Kristofferson'],
#  ['Dierks Bentley'],
#  ['Merle Haggard'],
#  ['George Strait'],
#  ['Brad Paisley'],
#  ['Hank Locklin'],
#  ['Conway Twitty'],
#  ['Willie Nelson'],
#  ['Jason Aldean'],
#  ['John Michael Montgomery'],
#  ['Marty Robbins'],
#  ['Rodney Atkins'],
#  ['Claude King'],
#  ['Alan Jackson'],
#  ['David Frizzell', 'Shelly West'],
#  ['Luke Bryan'],
#  ['Mary Chapin Carpenter'],
#  ['Waylon Jennings'],
#  ['Joe Nichols'],
#  ['Tom T. Hall'],
#  ['John Michael Montgomery'],
#  ['Zac Brown Band', 'Alan Jackson'],
#  ['Hank Williams', 'Drifting Cowboys'],
#  ['Lady A'],
#  ['Willie Nelson'],
#  ['Brooks & Dunn', 'Luke Combs'],
#  ['Ray Price'],
#  ['Billy Currington'],
#  ['Jeanne Pruett'],
#  ['Brett Eldredge'],
#  ['Kenny Rogers'],
#  ['Tammy Wynette'],
#  ['Blake Shelton'],
#  ['Travis Tritt'],
#  ['Eddie Rabbitt'],
#  ['Gary Allan'],
#  ['Deana Carter'],
#  ['George Jones'],
#  ['Loretta Lynn'],
#  ['Randy Travis'],
#  ['Jana Kramer'],
#  ['John Anderson'],
#  ['Waylon Jennings'],
#  ['Joe Nichols'],
#  ['Shania Twain'],
#  ['Porter Wagoner'],
#  ['Sam Hunt'],
#  ['Vince Gill'],
#  ['David Lee Murphy'],
#  ['Josh Turner'],
#  ['Buck Owens'],
#  ['Trisha Yearwood'],
#  ['Tracy Byrd'],
#  ['Dolly Parton'],
#  ['Kenny Chesney'],
#  ['Don Gibson'],
#  ['Hank Williams, Jr.'],
#  ['Luke Bryan'],
#  ['The Statler Brothers'],
#  ['The Judds'],
#  ['Tim McGraw'],
#  ['George Jones'],
#  ['Luke Bryan'],
#  ['Lorrie Morgan'],
#  ['Jack Greene'],
#  ['Alan Jackson'],
#  ['Kenny Rogers', 'Sheena Easton'],
#  ['Johnny Cash'],
#  ['Kenny Chesney'],
#  ['Waylon Jennings'],
#  ['Keith Whitley'],
#  ['Rodney Atkins'],
#  ['Shania Twain'],
#  ['Jason Aldean'],
#  ['Willie Nelson'],
#  ['Mark Chesnutt'],
#  ['Randy Houser'],
#  ['Merle Haggard'],
#  ['George Strait'],
#  ['Gary Allan'],
#  ['Johnny Paycheck'],
#  ['Faith Hill'],
#  ['Zac Brown Band', 'Jimmy Buffett'],
#  ['Tanya Tucker'],
#  ['Dierks Bentley'],
#  ['Little Texas'],
#  ['Sugarland'],
#  ['The Statler Brothers'],
#  ['Tim McGraw'],
#  ['Alan Jackson'],
#  ['Cole Swindell'],
#  ['Don Williams'],
#  ['George Strait'],
#  ['Lonestar'],
#  ['Kenny Rogers'],
#  ['Trace Adkins'],
#  ['Zac Brown Band'],
#  ['Brantley Gilbert'],
#  ['Bobby Bare'],
#  ['Shania Twain'],
#  ['Dierks Bentley'],
#  ['Merle Haggard & The Strangers'],
#  ['Jake Owen'],
#  ['Dwight Yoakam'],
#  ['Montgomery Gentry'],
#  ['Freddy Fender'],
#  ['Jason Aldean'],
#  ['John Conlee'],
#  ['Hal Ketchum'],
#  ['Jamey Johnson'],
#  ['Alan Jackson'],
#  ['Luke Bryan'],
#  ['Wynonna'],
#  ['Waylon Jennings'],
#  ['Kenny Chesney'],
#  ['Kenny Rogers'],
#  ['Carrie Underwood'],
#  ['Alabama'],
#  ['Brad Paisley'],
#  ['Steve Wariner'],
#  ['Alan Jackson'],
#  ['Chris Young'],
#  ['Merle Haggard', 'The Strangers'],
#  ['Restless Heart'],
#  ['Rascal Flatts'],
#  ['Ernest Tubb'],
#  ['Luke Bryan'],
#  ['John Michael Montgomery'],
#  ['Jason Aldean'],
#  ['Faron Young'],
#  ['Clint Black'],
#  ['Keith Urban'],
#  ['Willie Nelson'],
#  ['Brooks & Dunn', 'Brett Young'],
#  ['Sawyer Brown'],
#  ['Vern Gosdin'],
#  ['Lonestar'],
#  ['Tim McGraw'],
#  ['Taylor Swift'],
#  ['Loretta Lynn'],
#  ['Jason Aldean'],
#  ['Mel McDaniel'],
#  ['Kenny Chesney'],
#  ['Bobby Bare'],
#  ['Montgomery Gentry'],
#  ['Rosanne Cash'],
#  ['Rascal Flatts'],
#  ['Tammy Wynette'],
#  ['Lady A'],
#  ['Johnny Cash', 'June Carter Cash'],
#  ['Alabama'],
#  ['Chris Young'],
#  ['David Frizzell'],
#  ['Thomas Rhett'],
#  ['Dolly Parton'],
#  ['Kenny Rogers'],
#  ['Carrie Underwood'],
#  ['Buck Owens'],
#  ['Blake Shelton'],
#  ['Merle Haggard'],
#  ['Kenny Chesney'],
#  ['George Jones', 'The Jones Boys'],
#  ['Dwight Yoakam'],
#  ['Rodney Atkins'],
#  ['Hank Snow, The Singing Ranger, And His Rainbow Ranch Boys'],
#  ['Miranda Lambert'],
#  ['Tim McGraw'],
#  ['Conway Twitty'],
#  ['Lady A'],
#  ['Loretta Lynn'],
#  ['Chris Young'],
#  ['Carrie Underwood', 'Randy Travis'],
#  ['Randy Houser'],
#  ['Dottie West'],
#  ['Brooks & Dunn', 'Cody Johnson'],
#  ['Vince Gill'],
#  ['Tom T. Hall'],
#  ['Kip Moore'],
#  ['Zac Brown Band'],
#  ['Tim McGraw'],
#  ['Merle Haggard'],
#  ['Diamond Rio'],
#  ['Sawyer Brown'],
#  ['Mickey Gilley'],
#  ['Little Big Town'],
#  ['Collin Raye'],
#  ['Josh Turner'],
#  ['Lefty Frizzell'],
#  ['Alan Jackson'],
#  ['Brad Paisley'],
#  ['Henson Cargill'],
#  ['Tracy Lawrence'],
#  ['Tim McGraw'],
#  ['Crystal Gayle'],
#  ['Joe Diffie'],
#  ['Luke Bryan'],
#  ['Tom T. Hall'],
#  ['Lee Brice'],
#  ['George Strait'],
#  ['Restless Heart'],
#  ['Kenny Chesney'],
#  ['John Conlee'],
#  ['Miranda Lambert'],
#  ['Alabama'],
#  ['Rascal Flatts'],
#  ['Hank Williams', 'Drifting Cowboys'],
#  ['Don Williams'],
#  ['Heartland'],
#  ['Dolly Parton'],
#  ['Brad Paisley'],
#  ['Patty Loveless'],
#  ['Jason Aldean'],
#  ['Willie Nelson'],
#  ['Lady A'],
#  ['Anne Murray'],
#  ['Justin Moore'],
#  ['Linda Ronstadt'],
#  ['Eric Church'],
#  ['Dwight Yoakam'],
#  ['Ronnie Milsap'],
#  ['Blake Shelton'],
#  ['Mel Tillis'],
#  ['Martina McBride'],
#  ['Kenny Chesney'],
#  ['Marty Robbins'],
#  ['Brooks & Dunn'],
#  ['George Strait'],
#  ['Florida Georgia Line', 'Luke Bryan'],
#  ['John Anderson'],
#  ['Chris Young'],
#  ['Jerry Reed'],
#  ['Darius Rucker'],
#  ['Shania Twain'],
#  ['Waylon Jennings'],
#  ['Lady A'],
#  ['Gary Stewart'],
#  ['Trisha Yearwood'],
#  ['Kid Rock', 'Sheryl Crow'],
#  ['Brad Paisley', 'Alabama'],
#  ['The Chicks'],
#  ['Thomas Rhett'],
#  ['Zac Brown Band'],
#  ['Conway Twitty'],
#  ['Travis Tritt'],
#  ['Billy Currington'],
#  ['Restless Heart'],
#  ['Carrie Underwood'],
#  ['Sugarland'],
#  ['Waylon Jennings', 'Willie Nelson'],
#  ['Neal McCoy'],
#  ['Kenny Chesney', 'Uncle Kracker'],
#  ['Larry Gatlin & The Gatlin Brothers'],
#  ['Jessica Andrews'],
#  ['Tim McGraw'],
#  ['Willie Nelson'],
#  ['Sammy Kershaw'],
#  ['Montgomery Gentry'],
#  ['George Strait'],
#  ['Ernest Tubb'],
#  ['Doug Stone'],
#  ['Tyler Farr'],
#  ['Faith Hill'],
#  ['Mary Chapin Carpenter'],
#  ['Toby Keith'],
#  ['Tanya Tucker'],
#  ['Jake Owen'],
#  ['LeAnn Rimes'],
#  ['Freddie Hart'],
#  ['Dierks Bentley'],
#  ['Kenny Chesney'],
#  ['Kathy Mattea'],
#  ['Keith Urban'],
#  ['Hank Williams, Jr.'],
#  ['Merle Haggard'],
#  ['Thomas Rhett'],
#  ['Mel McDaniel'],
#  ['Willie Nelson'],
#  ['Tracy Byrd'],
#  ['The Wreckers'],
#  ['Tanya Tucker'],
#  ['Zac Brown Band'],
#  ['Martina McBride'],
#  ['Trace Adkins'],
#  ['Confederate Railroad'],
#  ['Patsy Cline', 'The Jordanaires'],
#  ['Toby Keith'],
#  ['Tim McGraw'],
#  ['Johnny Cash'],
#  ['Rascal Flatts'],
#  ['George Strait'],
#  ['Willie Nelson'],
#  ['Kenny Chesney'],
#  ['Easton Corbin'],
#  ['Hank Williams, Jr.', 'Reba McEntire', 'Willie Nelson', 'Tom Petty'],
#  ['Blake Shelton'],
#  ['Sylvia'],
#  ['Sara Evans'],
#  ['George Jones'],
#  ['Tracy Lawrence'],
#  ['John Conlee'],
#  ['Craig Morgan'],
#  ['Dolly Parton'],
#  ['Ernest Tubb'],
#  ['Dierks Bentley'],
#  ['John Anderson'],
#  ['Blake Shelton'],
#  ['Alabama'],
#  ['Sonny James'],
#  ['Jason Aldean'],
#  ['Wynn Stewart'],
#  ['Dwight Yoakam'],
#  ['Kenny Chesney'],
#  ['Reba McEntire', 'Linda Davis'],
#  ['Scotty McCreery'],
#  ['George Strait'],
#  ['Merle Haggard'],
#  ['Little Big Town'],
#  ['Tracy Byrd'],
#  ['Waylon Jennings'],
#  ['Jake Owen'],
#  ['Alan Jackson'],
#  ['Kenny Chesney', 'Grace Potter'],
#  ['Johnny Cash'],
#  ['Joe Diffie'],
#  ['Conway Twitty'],
#  ['Jason Aldean'],
#  ['Vince Gill'],
#  ['LeAnn Rimes'],
#  ['Brennen Leigh'],
#  ['Travis Tritt'],
#  ['Rascal Flatts'],
#  ['Brooks & Dunn', 'Tyler Booth'],
#  ['Easton Corbin'],
#  ['Willie Nelson', 'Ray Charles'],
#  ['George Strait'],
#  ['Carrie Underwood'],
#  ['George Jones'],
#  ['Tim McGraw'],
#  ['Roy Clark'],
#  ['Ronnie Milsap'],
#  ['Brad Paisley'],
#  ['Alabama'],
#  ['Billy Currington'],
#  ['Charley Pride'],
#  ['Mickey Gilley'],
#  ['Brett Eldredge'],
#  ['Brooks & Dunn', 'Midland'],
#  ['Carrie Underwood'],
#  ['Little Texas'],
#  ['David Allan Coe'],
#  ['Zac Brown Band'],
#  ['Mary Chapin Carpenter'],
#  ['Easton Corbin'],
#  ['George Jones'],
#  ['Mark Wills'],
#  ['Jason Aldean'],
#  ['Waylon Jennings'],
#  ['Dierks Bentley'],
#  ['Clint Black'],
#  ['Lee Ann Womack'],
#  ['Rascal Flatts'],
#  ['Mark Chesnutt'],
#  ['Kitty Wells'],
#  ['Steve Azar'],
#  ['Marty Robbins'],
#  ['George Strait'],
#  ['Lee Brice'],
#  ['Reba McEntire'],
#  ['Brad Paisley'],
#  ['Johnny Paycheck'],
#  ['Barbara Mandrell'],
#  ['Rascal Flatts'],
#  ['Doug Stone'],
#  ['Billy Currington'],
#  ['George Jones'],
#  ['Billy Dean'],
#  ['Brett Eldredge'],
#  ['Florida Georgia Line'],
#  ['Alan Jackson'],
#  ['Merle Haggard & The Strangers'],
#  ['Chris Young'],
#  ['Shania Twain'],
#  ['Gary Stewart'],
#  ['George Strait'],
#  ['George Strait'],
#  ['George Strait'],
#  ['George Strait'],
#  ['George Strait', 'Patty Loveless'],
#  ['George Strait'],
#  ['George Strait'],
#  ['George Strait'],
#  ['George Strait'],
#  ['George Strait', 'Dean Dillon'],
#  ['George Strait'],
#  ['George Strait'],
#  ['George Jones'],
#  ['Steve Wariner'],
#  ['Toby Keith', 'Willie Nelson'],
#  ['The Judds'],
#  ['Kenny Rogers & The First Edition'],
#  ['Big & Rich'],
#  ['Tim McGraw'],
#  ['Blake Shelton'],
#  ['Merle Haggard', 'The Strangers'],
#  ['Randy Houser'],
#  ['Dwight Yoakam'],
#  ['Blake Shelton', 'Pistol Annies'],
#  ['George Jones', 'Tammy Wynette'],
#  ['Chris Young'],
#  ['Phil Vassar'],
#  ['Faith Hill'],
#  ['Toby Keith'],
#  ['Tanya Tucker'],
#  ['Brad Paisley', 'Alison Krauss'],
#  ['LeAnn Rimes'],
#  ['Dierks Bentley'],
#  ['Bobby Bare'],
#  ['Tracy Lawrence'],
#  ['Collin Raye'],
#  ['Frankie Ballard'],
#  ['George Jones'],
#  ['Luke Bryan'],
#  ['Tracy Byrd'],
#  ['Conway Twitty'],
#  ['Jason Aldean'],
#  ['Terri Clark'],
#  ['Zac Brown Band'],
#  ['Merle Haggard'],
#  ['Cole Swindell'],
#  ['Shania Twain'],
#  ['Toby Keith'],
#  ['Clay Walker'],
#  ['Buck Owens'],
#  ['Brooks & Dunn'],
#  ['Billy Currington'],
#  ['Don Williams'],
#  ['Alabama'],
#  ['Brad Paisley'],
#  ['Jo Dee Messina'],
#  ['Willie Nelson'],
#  ['Tim McGraw', 'Taylor Swift', 'Keith Urban'],
#  ['The Chicks'],
#  ['Roy Clark'],
#  ['Blake Shelton'],
#  ['Carrie Underwood'],
#  ['Gene Watson'],
#  ['Brad Paisley', 'Dolly Parton'],
#  ['Reba McEntire'],
#  ['Jerrod Niemann'],
#  ['Johnny Cash'],
#  ['Clay Walker'],
#  ['The Bellamy Brothers'],
#  ['Kenny Chesney'],
#  ['Alabama'],
#  ['Lee Brice'],
#  ['Keith Whitley'],
#  ['Porter Wagoner', 'Dolly Parton'],
#  ['Blake Shelton'],
#  ['Randy Travis'],
#  ['Hank Williams', 'Drifting Cowboys'],
#  ['Steve Holy'],
#  ['Conway Twitty'],
#  ['Jerrod Niemann'],
#  ['Merle Haggard & The Strangers'],
#  ['Faith Hill'],
#  ['Trace Adkins'],
#  ['Thomas Rhett'],
#  ['George Jones'],
#  ['Mark Chesnutt'],
#  ['Randy Houser'],
#  ['Chris Young'],
#  ['Dolly Parton'],
#  ['Collin Raye'],
#  ['Billy Currington'],
#  ['Bob Luman'],
#  ['George Strait'],
#  ['Charley Pride'],
#  ['Sugarland'],
#  ['Alan Jackson'],
#  ['Tim McGraw'],
#  ['Tanya Tucker'],
#  ['Holly Dunn'],
#  ['Ray Charles'],
#  ['Mark Chesnutt'],
#  ['Carrie Underwood'],
#  ['Conway Twitty', 'Loretta Lynn'],
#  ['Toby Keith'],
#  ['Morgan Wallen'],
#  ['Midland'],
#  ['Jon Pardi'],
#  ['The Judds'],
#  ['Brooks & Dunn'],
#  ['Roger Miller'],
#  ['Brad Paisley'],
#  ['Jo Dee Messina'],
#  ['Dustin Lynch'],
#  ['Ronnie Milsap'],
#  ['Sugarland'],
#  ['Alabama'],
#  ['Eric Church'],
#  ['The Oak Ridge Boys'],
#  ['Joe Nichols']]

# %%
artist=[]
for i in artists_country:
    artist.append(", ".join(i))

# %%
artist
# Out:
# ['Patsy Cline, The Jordanaires',
#  'Johnny Cash, The Tennessee Two',
#  'Dolly Parton',
#  'Eric Church',
#  'George Jones',
#  'The Charlie Daniels Band',
#  'Roger Miller',
#  'Jason Aldean',
#  'Marty Robbins',
#  'Patsy Cline, The Jordanaires',
#  'Willie Nelson',
#  'Alabama',
#  'Kenny Chesney',
#  'Tammy Wynette',
#  'Alan Jackson',
#  'Johnny Cash',
#  'Tim McGraw',
#  'Hank Williams, Drifting Cowboys',
#  'Alison Krauss & Union Station',
#  'Eric Church',
#  'Waylon Jennings',
#  'Luke Bryan',
#  'Lee Greenwood',
#  'Conway Twitty',
#  'Florida Georgia Line',
#  'Johnny Lee',
#  'Johnny Lee',
#  'Johnny Lee',
#  'Johnny Lee',
#  'Johnny Lee',
#  'Johnny Lee',
#  'Johnny Lee',
#  'Johnny Lee',
#  'Johnny Lee',
#  'Johnny Lee',
#  'Loretta Lynn',
#  'Travis Tritt',
#  'Johnny Paycheck',
#  'Randy Travis',
#  'Merle Haggard',
#  'Tim McGraw',
#  'Brooks & Dunn, Kacey Musgraves',
#  'Jason Aldean',
#  'Kenny Rogers',
#  'Alan Jackson, Jimmy Buffett',
#  'Johnny Cash',
#  'Kenny Chesney',
#  'George Strait',
#  'Darius Rucker',
#  'Charley Pride',
#  'Zac Brown Band',
#  'Waylon Jennings, Willie Nelson',
#  'Reba McEntire',
#  'Hank Williams, Drifting Cowboys',
#  'The Chicks',
#  'Dave Dudley',
#  'Tim McGraw, Faith Hill',
#  'David Allan Coe',
#  'Taylor Swift',
#  'Johnny Cash',
#  'Dolly Parton, Kenny Rogers',
#  'Eli Young Band',
#  'Willie Nelson',
#  'Zac Brown Band',
#  'Patsy Cline',
#  'Brooks & Dunn, Thomas Rhett',
#  'Darius Rucker',
#  'Waylon Jennings, Willie Nelson',
#  'Kent Blazy & Garth Brooks',
#  'Lady A',
#  'Johnny Cash',
#  'The Chicks',
#  'Dolly Parton',
#  'Johnny Horton',
#  'Blake Shelton',
#  'Glen Campbell',
#  'Reba McEntire',
#  'Hank Williams, Drifting Cowboys',
#  'Brad Paisley',
#  'Martina McBride',
#  'Merle Haggard',
#  'Toby Keith',
#  'Johnny Cash',
#  'Eddie Rabbitt',
#  'Chris Young',
#  'Faron Young',
#  'Jimmy Buffett',
#  'Luke Bryan',
#  'Don Williams',
#  'Jimmy Dean',
#  'Sammy Kershaw',
#  'Dierks Bentley',
#  'Conway Twitty, Loretta Lynn',
#  'Ronnie Milsap',
#  'Roger Miller',
#  'Tim McGraw',
#  'Charley Pride',
#  'The Bellamy Brothers',
#  'Tennessee Ernie Ford',
#  'Kenny Chesney',
#  'Hank Williams',
#  'Alabama',
#  'Blake Shelton',
#  'Willie Nelson',
#  'Lonestar',
#  'Chris Young',
#  'Buck Owens',
#  'Juice Newton',
#  'Bobbie Gentry',
#  'Kenny Chesney',
#  'Linda Ronstadt',
#  'Roger Miller',
#  'Diamond Rio',
#  'Tom T. Hall',
#  'Gary Allan',
#  'Patsy Cline',
#  'George Strait',
#  'Johnny Cash',
#  'Billy Currington',
#  'Trisha Yearwood',
#  'Hank Williams, Drifting Cowboys',
#  'Brad Paisley, Carrie Underwood',
#  'Johnny Paycheck',
#  'Kenny Rogers',
#  'Loretta Lynn',
#  'Rodney Atkins',
#  'Floyd Cramer',
#  'Clint Black',
#  'The Highwaymen, Willie Nelson, Johnny Cash, Waylon Jennings, Kris Kristofferson',
#  'Craig Morgan',
#  'George Strait',
#  'Marty Robbins',
#  'Darius Rucker',
#  'Lynn Anderson',
#  'Alan Jackson',
#  'Sammi Smith',
#  'Mark Wills',
#  'George Jones',
#  'The Statler Brothers',
#  'John Michael Montgomery',
#  'Leroy Van Dyke',
#  'Rascal Flatts',
#  'Johnny Cash, June Carter Cash',
#  'Eddie Rabbitt',
#  'Don Gibson',
#  'James Otto',
#  'Charlie Rich',
#  'Nitty Gritty Dirt Band',
#  'Tammy Wynette',
#  'Sara Evans',
#  'Merle Haggard & The Strangers',
#  'Toby Keith',
#  'Kenny Chesney',
#  'Willie Nelson, Chris Stapleton',
#  'Tim McGraw',
#  'Buck Owens',
#  'Darius Rucker',
#  'Juice Newton',
#  'Eddy Arnold',
#  'Sugarland',
#  'Ronnie Milsap',
#  'Tanya Tucker',
#  'George Strait',
#  'Marty Robbins',
#  'Thompson Square',
#  'Willie Nelson',
#  'Alan Jackson',
#  'Loretta Lynn',
#  'John Michael Montgomery',
#  'Chris Cagle',
#  'Kenny Rogers',
#  'Jo Dee Messina',
#  'Johnny Horton',
#  'Zac Brown Band',
#  'Ferlin Husky, Hank Locklin',
#  'Dolly Parton, Tammy Wynette, Loretta Lynn',
#  'Ronnie Milsap',
#  'Johnny Cash',
#  'Kenny Chesney',
#  'Pam Tillis',
#  'Conway Twitty',
#  'The Band Perry',
#  'Jim Ed Brown',
#  'Randy Travis',
#  'Brad Paisley',
#  'Loretta Lynn',
#  'Alan Jackson',
#  'Keith Urban',
#  'Guy Mitchell',
#  'Miranda Lambert',
#  'Brooks & Dunn',
#  'Roger Miller',
#  'Kenny Chesney',
#  'Johnny Cash, Tennessee Three',
#  'Barbara Mandrell, George Jones',
#  'Waylon Jennings',
#  'Luke Bryan',
#  'Freddy Fender',
#  'Hunter Hayes',
#  'John Michael Montgomery',
#  'Kenny Rogers',
#  'Carrie Underwood',
#  'Eddie Rabbitt, Crystal Gayle',
#  'Jason Aldean, Kelly Clarkson',
#  'Skeeter Davis',
#  'Alabama',
#  'Kenny Chesney',
#  'Del Reeves',
#  'Faith Hill',
#  'Charlie Rich',
#  'The Oak Ridge Boys',
#  'Kelsea Ballerini',
#  'Merle Haggard',
#  'The Browns',
#  'Kenny Rogers',
#  'Trace Adkins',
#  'Bobby Bare',
#  'Toby Keith',
#  'Hank Williams, Drifting Cowboys',
#  'Joe Nichols',
#  'Ronnie Milsap',
#  'Kenny Chesney',
#  'Jim Reeves',
#  'Lee Brice',
#  'Willie Nelson, Merle Haggard',
#  'Alabama',
#  'Jana Kramer',
#  'Glen Campbell',
#  'Shenandoah',
#  'Josh Turner',
#  'Hank Snow',
#  'Billy Currington',
#  'George Jones, Tammy Wynette',
#  'Hank Williams, Jr.',
#  'Keith Urban',
#  'Ray Charles',
#  'Luke Bryan',
#  'Patsy Cline',
#  'Tim McGraw',
#  'Waylon Jennings',
#  'Eli Young Band',
#  'George Hamilton IV',
#  'Faith Hill',
#  'Brantley Gilbert',
#  'Clint Black',
#  'Kris Kristofferson',
#  'Dierks Bentley',
#  'Merle Haggard',
#  'George Strait',
#  'Brad Paisley',
#  'Hank Locklin',
#  'Conway Twitty',
#  'Willie Nelson',
#  'Jason Aldean',
#  'John Michael Montgomery',
#  'Marty Robbins',
#  'Rodney Atkins',
#  'Claude King',
#  'Alan Jackson',
#  'David Frizzell, Shelly West',
#  'Luke Bryan',
#  'Mary Chapin Carpenter',
#  'Waylon Jennings',
#  'Joe Nichols',
#  'Tom T. Hall',
#  'John Michael Montgomery',
#  'Zac Brown Band, Alan Jackson',
#  'Hank Williams, Drifting Cowboys',
#  'Lady A',
#  'Willie Nelson',
#  'Brooks & Dunn, Luke Combs',
#  'Ray Price',
#  'Billy Currington',
#  'Jeanne Pruett',
#  'Brett Eldredge',
#  'Kenny Rogers',
#  'Tammy Wynette',
#  'Blake Shelton',
#  'Travis Tritt',
#  'Eddie Rabbitt',
#  'Gary Allan',
#  'Deana Carter',
#  'George Jones',
#  'Loretta Lynn',
#  'Randy Travis',
#  'Jana Kramer',
#  'John Anderson',
#  'Waylon Jennings',
#  'Joe Nichols',
#  'Shania Twain',
#  'Porter Wagoner',
#  'Sam Hunt',
#  'Vince Gill',
#  'David Lee Murphy',
#  'Josh Turner',
#  'Buck Owens',
#  'Trisha Yearwood',
#  'Tracy Byrd',
#  'Dolly Parton',
#  'Kenny Chesney',
#  'Don Gibson',
#  'Hank Williams, Jr.',
#  'Luke Bryan',
#  'The Statler Brothers',
#  'The Judds',
#  'Tim McGraw',
#  'George Jones',
#  'Luke Bryan',
#  'Lorrie Morgan',
#  'Jack Greene',
#  'Alan Jackson',
#  'Kenny Rogers, Sheena Easton',
#  'Johnny Cash',
#  'Kenny Chesney',
#  'Waylon Jennings',
#  'Keith Whitley',
#  'Rodney Atkins',
#  'Shania Twain',
#  'Jason Aldean',
#  'Willie Nelson',
#  'Mark Chesnutt',
#  'Randy Houser',
#  'Merle Haggard',
#  'George Strait',
#  'Gary Allan',
#  'Johnny Paycheck',
#  'Faith Hill',
#  'Zac Brown Band, Jimmy Buffett',
#  'Tanya Tucker',
#  'Dierks Bentley',
#  'Little Texas',
#  'Sugarland',
#  'The Statler Brothers',
#  'Tim McGraw',
#  'Alan Jackson',
#  'Cole Swindell',
#  'Don Williams',
#  'George Strait',
#  'Lonestar',
#  'Kenny Rogers',
#  'Trace Adkins',
#  'Zac Brown Band',
#  'Brantley Gilbert',
#  'Bobby Bare',
#  'Shania Twain',
#  'Dierks Bentley',
#  'Merle Haggard & The Strangers',
#  'Jake Owen',
#  'Dwight Yoakam',
#  'Montgomery Gentry',
#  'Freddy Fender',
#  'Jason Aldean',
#  'John Conlee',
#  'Hal Ketchum',
#  'Jamey Johnson',
#  'Alan Jackson',
#  'Luke Bryan',
#  'Wynonna',
#  'Waylon Jennings',
#  'Kenny Chesney',
#  'Kenny Rogers',
#  'Carrie Underwood',
#  'Alabama',
#  'Brad Paisley',
#  'Steve Wariner',
#  'Alan Jackson',
#  'Chris Young',
#  'Merle Haggard, The Strangers',
#  'Restless Heart',
#  'Rascal Flatts',
#  'Ernest Tubb',
#  'Luke Bryan',
#  'John Michael Montgomery',
#  'Jason Aldean',
#  'Faron Young',
#  'Clint Black',
#  'Keith Urban',
#  'Willie Nelson',
#  'Brooks & Dunn, Brett Young',
#  'Sawyer Brown',
#  'Vern Gosdin',
#  'Lonestar',
#  'Tim McGraw',
#  'Taylor Swift',
#  'Loretta Lynn',
#  'Jason Aldean',
#  'Mel McDaniel',
#  'Kenny Chesney',
#  'Bobby Bare',
#  'Montgomery Gentry',
#  'Rosanne Cash',
#  'Rascal Flatts',
#  'Tammy Wynette',
#  'Lady A',
#  'Johnny Cash, June Carter Cash',
#  'Alabama',
#  'Chris Young',
#  'David Frizzell',
#  'Thomas Rhett',
#  'Dolly Parton',
#  'Kenny Rogers',
#  'Carrie Underwood',
#  'Buck Owens',
#  'Blake Shelton',
#  'Merle Haggard',
#  'Kenny Chesney',
#  'George Jones, The Jones Boys',
#  'Dwight Yoakam',
#  'Rodney Atkins',
#  'Hank Snow, The Singing Ranger, And His Rainbow Ranch Boys',
#  'Miranda Lambert',
#  'Tim McGraw',
#  'Conway Twitty',
#  'Lady A',
#  'Loretta Lynn',
#  'Chris Young',
#  'Carrie Underwood, Randy Travis',
#  'Randy Houser',
#  'Dottie West',
#  'Brooks & Dunn, Cody Johnson',
#  'Vince Gill',
#  'Tom T. Hall',
#  'Kip Moore',
#  'Zac Brown Band',
#  'Tim McGraw',
#  'Merle Haggard',
#  'Diamond Rio',
#  'Sawyer Brown',
#  'Mickey Gilley',
#  'Little Big Town',
#  'Collin Raye',
#  'Josh Turner',
#  'Lefty Frizzell',
#  'Alan Jackson',
#  'Brad Paisley',
#  'Henson Cargill',
#  'Tracy Lawrence',
#  'Tim McGraw',
#  'Crystal Gayle',
#  'Joe Diffie',
#  'Luke Bryan',
#  'Tom T. Hall',
#  'Lee Brice',
#  'George Strait',
#  'Restless Heart',
#  'Kenny Chesney',
#  'John Conlee',
#  'Miranda Lambert',
#  'Alabama',
#  'Rascal Flatts',
#  'Hank Williams, Drifting Cowboys',
#  'Don Williams',
#  'Heartland',
#  'Dolly Parton',
#  'Brad Paisley',
#  'Patty Loveless',
#  'Jason Aldean',
#  'Willie Nelson',
#  'Lady A',
#  'Anne Murray',
#  'Justin Moore',
#  'Linda Ronstadt',
#  'Eric Church',
#  'Dwight Yoakam',
#  'Ronnie Milsap',
#  'Blake Shelton',
#  'Mel Tillis',
#  'Martina McBride',
#  'Kenny Chesney',
#  'Marty Robbins',
#  'Brooks & Dunn',
#  'George Strait',
#  'Florida Georgia Line, Luke Bryan',
#  'John Anderson',
#  'Chris Young',
#  'Jerry Reed',
#  'Darius Rucker',
#  'Shania Twain',
#  'Waylon Jennings',
#  'Lady A',
#  'Gary Stewart',
#  'Trisha Yearwood',
#  'Kid Rock, Sheryl Crow',
#  'Brad Paisley, Alabama',
#  'The Chicks',
#  'Thomas Rhett',
#  'Zac Brown Band',
#  'Conway Twitty',
#  'Travis Tritt',
#  'Billy Currington',
#  'Restless Heart',
#  'Carrie Underwood',
#  'Sugarland',
#  'Waylon Jennings, Willie Nelson',
#  'Neal McCoy',
#  'Kenny Chesney, Uncle Kracker',
#  'Larry Gatlin & The Gatlin Brothers',
#  'Jessica Andrews',
#  'Tim McGraw',
#  'Willie Nelson',
#  'Sammy Kershaw',
#  'Montgomery Gentry',
#  'George Strait',
#  'Ernest Tubb',
#  'Doug Stone',
#  'Tyler Farr',
#  'Faith Hill',
#  'Mary Chapin Carpenter',
#  'Toby Keith',
#  'Tanya Tucker',
#  'Jake Owen',
#  'LeAnn Rimes',
#  'Freddie Hart',
#  'Dierks Bentley',
#  'Kenny Chesney',
#  'Kathy Mattea',
#  'Keith Urban',
#  'Hank Williams, Jr.',
#  'Merle Haggard',
#  'Thomas Rhett',
#  'Mel McDaniel',
#  'Willie Nelson',
#  'Tracy Byrd',
#  'The Wreckers',
#  'Tanya Tucker',
#  'Zac Brown Band',
#  'Martina McBride',
#  'Trace Adkins',
#  'Confederate Railroad',
#  'Patsy Cline, The Jordanaires',
#  'Toby Keith',
#  'Tim McGraw',
#  'Johnny Cash',
#  'Rascal Flatts',
#  'George Strait',
#  'Willie Nelson',
#  'Kenny Chesney',
#  'Easton Corbin',
#  'Hank Williams, Jr., Reba McEntire, Willie Nelson, Tom Petty',
#  'Blake Shelton',
#  'Sylvia',
#  'Sara Evans',
#  'George Jones',
#  'Tracy Lawrence',
#  'John Conlee',
#  'Craig Morgan',
#  'Dolly Parton',
#  'Ernest Tubb',
#  'Dierks Bentley',
#  'John Anderson',
#  'Blake Shelton',
#  'Alabama',
#  'Sonny James',
#  'Jason Aldean',
#  'Wynn Stewart',
#  'Dwight Yoakam',
#  'Kenny Chesney',
#  'Reba McEntire, Linda Davis',
#  'Scotty McCreery',
#  'George Strait',
#  'Merle Haggard',
#  'Little Big Town',
#  'Tracy Byrd',
#  'Waylon Jennings',
#  'Jake Owen',
#  'Alan Jackson',
#  'Kenny Chesney, Grace Potter',
#  'Johnny Cash',
#  'Joe Diffie',
#  'Conway Twitty',
#  'Jason Aldean',
#  'Vince Gill',
#  'LeAnn Rimes',
#  'Brennen Leigh',
#  'Travis Tritt',
#  'Rascal Flatts',
#  'Brooks & Dunn, Tyler Booth',
#  'Easton Corbin',
#  'Willie Nelson, Ray Charles',
#  'George Strait',
#  'Carrie Underwood',
#  'George Jones',
#  'Tim McGraw',
#  'Roy Clark',
#  'Ronnie Milsap',
#  'Brad Paisley',
#  'Alabama',
#  'Billy Currington',
#  'Charley Pride',
#  'Mickey Gilley',
#  'Brett Eldredge',
#  'Brooks & Dunn, Midland',
#  'Carrie Underwood',
#  'Little Texas',
#  'David Allan Coe',
#  'Zac Brown Band',
#  'Mary Chapin Carpenter',
#  'Easton Corbin',
#  'George Jones',
#  'Mark Wills',
#  'Jason Aldean',
#  'Waylon Jennings',
#  'Dierks Bentley',
#  'Clint Black',
#  'Lee Ann Womack',
#  'Rascal Flatts',
#  'Mark Chesnutt',
#  'Kitty Wells',
#  'Steve Azar',
#  'Marty Robbins',
#  'George Strait',
#  'Lee Brice',
#  'Reba McEntire',
#  'Brad Paisley',
#  'Johnny Paycheck',
#  'Barbara Mandrell',
#  'Rascal Flatts',
#  'Doug Stone',
#  'Billy Currington',
#  'George Jones',
#  'Billy Dean',
#  'Brett Eldredge',
#  'Florida Georgia Line',
#  'Alan Jackson',
#  'Merle Haggard & The Strangers',
#  'Chris Young',
#  'Shania Twain',
#  'Gary Stewart',
#  'George Strait',
#  'George Strait',
#  'George Strait',
#  'George Strait',
#  'George Strait, Patty Loveless',
#  'George Strait',
#  'George Strait',
#  'George Strait',
#  'George Strait',
#  'George Strait, Dean Dillon',
#  'George Strait',
#  'George Strait',
#  'George Jones',
#  'Steve Wariner',
#  'Toby Keith, Willie Nelson',
#  'The Judds',
#  'Kenny Rogers & The First Edition',
#  'Big & Rich',
#  'Tim McGraw',
#  'Blake Shelton',
#  'Merle Haggard, The Strangers',
#  'Randy Houser',
#  'Dwight Yoakam',
#  'Blake Shelton, Pistol Annies',
#  'George Jones, Tammy Wynette',
#  'Chris Young',
#  'Phil Vassar',
#  'Faith Hill',
#  'Toby Keith',
#  'Tanya Tucker',
#  'Brad Paisley, Alison Krauss',
#  'LeAnn Rimes',
#  'Dierks Bentley',
#  'Bobby Bare',
#  'Tracy Lawrence',
#  'Collin Raye',
#  'Frankie Ballard',
#  'George Jones',
#  'Luke Bryan',
#  'Tracy Byrd',
#  'Conway Twitty',
#  'Jason Aldean',
#  'Terri Clark',
#  'Zac Brown Band',
#  'Merle Haggard',
#  'Cole Swindell',
#  'Shania Twain',
#  'Toby Keith',
#  'Clay Walker',
#  'Buck Owens',
#  'Brooks & Dunn',
#  'Billy Currington',
#  'Don Williams',
#  'Alabama',
#  'Brad Paisley',
#  'Jo Dee Messina',
#  'Willie Nelson',
#  'Tim McGraw, Taylor Swift, Keith Urban',
#  'The Chicks',
#  'Roy Clark',
#  'Blake Shelton',
#  'Carrie Underwood',
#  'Gene Watson',
#  'Brad Paisley, Dolly Parton',
#  'Reba McEntire',
#  'Jerrod Niemann',
#  'Johnny Cash',
#  'Clay Walker',
#  'The Bellamy Brothers',
#  'Kenny Chesney',
#  'Alabama',
#  'Lee Brice',
#  'Keith Whitley',
#  'Porter Wagoner, Dolly Parton',
#  'Blake Shelton',
#  'Randy Travis',
#  'Hank Williams, Drifting Cowboys',
#  'Steve Holy',
#  'Conway Twitty',
#  'Jerrod Niemann',
#  'Merle Haggard & The Strangers',
#  'Faith Hill',
#  'Trace Adkins',
#  'Thomas Rhett',
#  'George Jones',
#  'Mark Chesnutt',
#  'Randy Houser',
#  'Chris Young',
#  'Dolly Parton',
#  'Collin Raye',
#  'Billy Currington',
#  'Bob Luman',
#  'George Strait',
#  'Charley Pride',
#  'Sugarland',
#  'Alan Jackson',
#  'Tim McGraw',
#  'Tanya Tucker',
#  'Holly Dunn',
#  'Ray Charles',
#  'Mark Chesnutt',
#  'Carrie Underwood',
#  'Conway Twitty, Loretta Lynn',
#  'Toby Keith',
#  'Morgan Wallen',
#  'Midland',
#  'Jon Pardi',
#  'The Judds',
#  'Brooks & Dunn',
#  'Roger Miller',
#  'Brad Paisley',
#  'Jo Dee Messina',
#  'Dustin Lynch',
#  'Ronnie Milsap',
#  'Sugarland',
#  'Alabama',
#  'Eric Church',
#  'The Oak Ridge Boys',
#  'Joe Nichols']

# %% [markdown]
# ### Getting track ids

# %%
track_id=[]

# %%
for i in range(0, len(tracks_country)):
    track_id.append(tracks_country[i]['track']['id'])

# %%
track_id
# Out:
# ['3zpj9dvJABiyMrmLCPw6i8',
#  '121sjkub4p4zcFNozkKnQD',
#  '6nRvgo4ySezQKD1D7NIqAu',
#  '05ZACkzW8YbRq3eFgIfSNB',
#  '6qMgx8ys4MNNxypaIvbG0i',
#  '383Xl5QTigwj3QiA3Qc6S7',
#  '0tm2gY77p2X7BsSWRq0cBk',
#  '7awFBRzXpFoy8YIm9zOb5s',
#  '4f8hBeMXMvssn6HtFAtblo',
#  '6zFsz86nAj5gcvzyVqNL3k',
#  '3MpK9vnxxgYvh0CNeGvx6G',
#  '7BjmEKAVTnJNkRNaUzBy2K',
#  '2HmMklpgK8vGCpJmPpz1yG',
#  '6xatfNMI8NkY5XxRHAeiS4',
#  '26iYJEimPCE0ozDlpj0UFN',
#  '6YffUZJ2R06kyxyK6onezL',
#  '7B1QliUMZv7gSTUGAfMRRD',
#  '73HgnHCHDEZCmtMpEzxnO0',
#  '6HveTIMynTMzTc5L0TcS20',
#  '1cktZnxiONH0hR6Q3DKy8h',
#  '6ANPIv5r3vdWntrmFa6H6M',
#  '03fT3OHB9KyMtGMt2zwqCT',
#  '3DWGiPUy9PhJIMOt1SRIVL',
#  '6vmAgl2y9MpoZKrVUXrPe5',
#  '1aS5oaBNG6wsf186ZZMCzX',
#  '1GZPwcq6wQ5XimwWxQy6sy',
#  '6oLb7W5ALa0i3cd4bQanEU',
#  '2tyGwTGnMrO3rFeRm9hpw5',
#  '1GQg6OaA6G5L94Kniz8Vol',
#  '43J5oKpADrahUqE5VVeKcD',
#  '6rO3H8372xNbIp6lxvbSpu',
#  '6Sqnw4eNhs8vP1q9U0RXQT',
#  '1nFbE2x7KrUOoLlCgix5ZO',
#  '6bY64DOIOx9BcWD1kGfAME',
#  '2QsMmg5uwLy3EIGA8HLszU',
#  '3mM14WXoPaLRjjkmxHe99L',
#  '3oW6SWwGqiZSPTiAp7ZQoH',
#  '6yT7kcpsXNW7QS9xunPaox',
#  '4rQSLX4qMiUWL81hEQOuPY',
#  '3clB1MI7aKn0N9X1KuWK8n',
#  '2iTRea118VRKRUzrGjjlHP',
#  '3lVPtkNFoIyPPGVdNri4VH',
#  '1jvUrVUMm1U2XfXX534fRP',
#  '5KqldkCunQ2rWxruMEtGh0',
#  '5oHHMDcVOmPSFrCgdbHPdb',
#  '5xMNjx7uqCzMpJZSo4Wq55',
#  '6reuJxDtjebwc9FB6rNpp0',
#  '7k1Xm1wy00hCKJDYJL5p1n',
#  '3xdjjKMcMOFgo1eQrfbogM',
#  '1gNUf7ItWfqwFrpDWzYcYY',
#  '3U8dHeggJ8IBe0UCb1gbyB',
#  '3CqLvQ9fPOLtLIKb7r5ti6',
#  '1ecIqo8pOc8S6y3l80iGxd',
#  '7tNJo8NJ7fhprfjyDgdH2A',
#  '3rXCZRMiMZp0feGcYXpwYX',
#  '1tswBQlL2Bklbb82GHxKoW',
#  '7nEdCj0MFbGWOxwjlpPesa',
#  '29TI0GvP5gMQMPTJjdMe0H',
#  '7DQmwd7zye9xvzMQJnD8S8',
#  '5KF3zQP0cqLklYnF6riogg',
#  '4dqEzdFAYkj1rjYLVDuTlN',
#  '1nVLAEzhBXMJLR5zAl90Nl',
#  '2xYQTU2bbg6WVAmpY1eae4',
#  '0LQtEJt7x0s6knb6RKdRYc',
#  '22IXwYrhwf2mYCkVlF0Ulo',
#  '64vkacv9XtTjAQSosbUbW2',
#  '5JlH51YDYsGj2dyEJKKjcN',
#  '1gKSpFpX3poa17WIAyFVsp',
#  '6J4WWvwcWoW1DiZFoE7YfX',
#  '11EX5yhxr9Ihl3IN1asrfK',
#  '15TITugVC8RrpLctHXOqT8',
#  '5hviCr3lgg6LY6noG6DPKs',
#  '4w3tQBXhn5345eUXDGBWZG',
#  '1XRA4Tjb2YrcQU5ThDllCw',
#  '03IdmP4frla6BCFZH6rkaF',
#  '0mLoTgCB8oU0sJGojRtvDu',
#  '2MiXC2LfpsoeUP5RvMGEQ3',
#  '0iSgP007c2uYck3dq5ltIM',
#  '2rQyI7A1yTvTXJ9J4qFmmN',
#  '2jOkuPweyFcDBBBF8ZW8Zr',
#  '7tvnZH4Db2zylKHo7ojKH1',
#  '4EDBgrYqYQ6b50yhJWKsHp',
#  '7hxZF4jETnE5Q75rKQnMjE',
#  '3PJ9yQv8IUmLx24KFvaVEI',
#  '28Sc21lrWcZD9Ov4rRkPJq',
#  '4dim8F8t01qimHOmr6S3Gd',
#  '4EEjMyQub6tgFVshlM9j1M',
#  '1PoGWZbJPGmViVi7CYbDUK',
#  '0cThXovxrvU68JuzYUXhJT',
#  '61uAY9xdzYiIbYJ07XvKso',
#  '2oyS4THTUzUxT2lnHGzzIr',
#  '1soxUgYIZb1qx1c7o1Lc7z',
#  '02sENi9ULQ36x9mKo5B7XW',
#  '7CX9JYwpiObnYl2NzFqj4c',
#  '20iH1uibQIUqNFk3wzG7AG',
#  '1zG6cEmeo4rv7Old8XD7vC',
#  '6wAD64HhuMcXGA4Z64BLqq',
#  '064SVQsmWl5EF0zahmzkQk',
#  '3P6OwCX7Ofiaaqtvujb6i5',
#  '3QV7NYkrmV0Q0IHdFJw9hO',
#  '0hveAq1VSNWo9MQYGMHvFF',
#  '225W9qCk2o51QyFZiEVDW9',
#  '0U3xEfWLX4slslHJaAorSw',
#  '2uRVPeQbsEpRQD0DKr1WTo',
#  '6iNcyWk5iUEY7P9zeTc5hm',
#  '0H04yVa3DJxoXbLBpAb7iV',
#  '1GDAvJth0ebssC2XkG7RYM',
#  '6NVB6W7G3svCKe5zB7kY8q',
#  '4FdDorlbJTVHcH3djLbIfn',
#  '3tHPjLBakLS48aumhFpJMt',
#  '79EctjVa6Z8tDmjnGWC03c',
#  '3vMwtAfDNM8dDBWMvS78pn',
#  '7lUE02KHkZM44BZgjCaWRO',
#  '2vhFsRat25P9D8rweQF1Jq',
#  '63u5QGp9dKXAoYTVKUKBYn',
#  '2JKPDzbXrFT3rCFcUtVzoT',
#  '6FHXJu99aQAUnivEjPhuUR',
#  '7robBaDSeyFRaxT0QhBifa',
#  '7GQjJEwqlp6m5HNWVQd6OR',
#  '4EJvW4NHAk7TrIeX44jjXF',
#  '1l5WwxtivtUrg1SCHYzFls',
#  '4ABua0yuWcpTotImEEJTaw',
#  '3w3vrnY530BeHUDWRcHrp9',
#  '5Pj5zrq2nbKcAekH1AxbrO',
#  '5XOM6Neo5IACRMhvd2ibKA',
#  '7B6m8tHAYZsOKOKMU5SR2n',
#  '1mcNoPKzV3AqlkRW04SWvr',
#  '64wIcMPOnEyBuxSTOU3KUj',
#  '7jWbXvrgdbkajU8L28ahn5',
#  '1fmi1hOBtH8xfUiWz4LVtE',
#  '4TnUKixNWMfajncgdSwFoi',
#  '58ojWS1EGL6z5rEOELtJmH',
#  '0XfFxeXzMkIy5SWAVpOQin',
#  '5YwgJ6lpZ3SiAQwBEpjqey',
#  '2CBRlZtrYrhd8XXFFDSxAl',
#  '2XWmbwp9FBAaFcSE9BLQzc',
#  '56coXX3B2Jns6jxbssJv0y',
#  '1q0SkvboXCdVQauHBzVr9z',
#  '7ledv9CTjqdwnvHgRmETyZ',
#  '19lw4C2aW6TYvxqRsek2Kd',
#  '2EI50XcYPyKjx4rGbgihAk',
#  '4bVuIlGQBMWS7vIhcx8Ae4',
#  '5fcxVCOtfesNzI2n4Y4kiJ',
#  '0zvNHIL7ci0ZzIoWU6RO2u',
#  '7pE3xCbi3P4OyHWzONRZwB',
#  '4b0XF7CDpJEBAdVHMw7amV',
#  '5kXmiepRVuKhhz0SxyCVeL',
#  '7lJbTVbDEMa3w7NFamrwdq',
#  '4JPEuPsDG3nNJMAvvQ2Rr3',
#  '6NhpIdjYoufuNNlBsgOztc',
#  '04ilBEd1FVUhpv9ItR6yTN',
#  '3acc39xylOcBe7hIMkdeum',
#  '04ccQGJ1i8gL7JoeCPiJbv',
#  '6LwFptnDWoGKTdhAFNjVQF',
#  '0nDjzA4kns1QOWPXuOn6Xw',
#  '3JWEMzwpcWCvu4Qw1BIbYi',
#  '4gzeYkzuzxuzAUTsGcdjqA',
#  '6xBUWSz8INNHO6wFYuPtQl',
#  '7GafJyGdVj7ahXo96LwFM4',
#  '40bd032FvXsRP6QIeKkANi',
#  '1PTngmREtR0P0YMLdqVWBj',
#  '7GH8qNOm2gEKryVUyVzkmt',
#  '4G9eIyEcVwLoG7kYNFpSII',
#  '0AQquaENerGps8BQmbPw14',
#  '2TAcwD5KcV9uY3O1tLGV15',
#  '7aVapcvsbFYYmcQvhkc8Rc',
#  '0zguOtmQBHtdzIG35vZilH',
#  '1Ch2cPleHoVVXLVRRrGF6o',
#  '7wIaLkbQzG6HMnE28etnif',
#  '7uPReljrrTaqzDCcx4JHmi',
#  '15ADURMdkO25JGD5mIcodM',
#  '6Lmx6bz3PGYuNSjKMnYBOa',
#  '4mCB2FpWvmT3GcXUWyn0gs',
#  '4S518ci8UY4op0Xyp6Hx6o',
#  '31vF1iGX0S3Dtv0rQfEksJ',
#  '2UOXPChomSLn151c0aboSx',
#  '7sNKhnl4MZnHdMzvmC4jG5',
#  '3I1vEQhGwRK7URrTq4BqNl',
#  '0Ox458KpvZQ1Kuj9mUNPLL',
#  '3wjD3Ufjll7UKrEDPdGuX3',
#  '1QBhszc25PesXgxCOAIdI2',
#  '4aY0tZIaboefmkBEsjAovI',
#  '73AgVwYUEPn9kB0a97b4LW',
#  '3xx0jE52PbtvwXgNaBUdch',
#  '4HHtqzri9jrmAGFyucxkLG',
#  '1kQ72jbOMbGhZgQsylugAt',
#  '3oyByfBYegVEDwYyqx9pRd',
#  '7MtZJEuIZ6GEKGSN7ttTkX',
#  '1KcSPQqbbbBCFyAVmJySst',
#  '02eD9ymfJOJOhM97HYp5R9',
#  '7K1a1MSYYqTgPofuGD6ctM',
#  '2vnaSKQS0QmmOMXchE1t8y',
#  '1CjQCQsl9FDb3WhjGcFOzG',
#  '1sueD22EyCamMjdQu9Kuo3',
#  '2jQw7zMJO4fekTbP7iVA4v',
#  '7FYQ5lnm0aSw5gughyiDkr',
#  '1YhFtqwcN138S6ng3MT1nN',
#  '0Ao3qWJKueyfs3iqwGN30F',
#  '0f1svjHSiaCJif6noKKVHa',
#  '6MnDkyb3VstTCT9ELxjfeE',
#  '5lwDkNZxwGNzJMh2eanLFM',
#  '2dRPQFwPqAmc42mDRnsDQu',
#  '7sWlOFUnQShNdxgk1B0TuW',
#  '2usybbJIyVPm1aeGK2bitr',
#  '5DTOOkooKFUvWj1XQTFa09',
#  '2uX5f3x2cObov0iDAPln4o',
#  '1dgWTMoHwTUnQhOQ8SR5fV',
#  '6ZNqzdQ65tLk7fnxwch6LG',
#  '3y4LxiYMgDl4RethdzpmNe',
#  '4NRFiS0pHjTFDjOm1LWTZj',
#  '0mG66FLhO0iZ6XCAGdjpax',
#  '5JgNsYcjcSk4bYiZjYE7tL',
#  '1BvL1umLZqA3MNhRVFzIyI',
#  '24SbmQo3XQkNLpSBYda4DA',
#  '5ggOAMsJCAYDHnyoqJ0xAD',
#  '7Efs0OIW6zgQyH7ehKZYpN',
#  '7eNM9suHz80f4fbC8aobod',
#  '21rPFUpYjGKXjwrN13cHv6',
#  '5hwgwSJrc1NDmBZwmBYX4i',
#  '43lL05gZ1DqG4YJ74rCPmM',
#  '0phpkeFYmnW1p8oLmmGRFT',
#  '58dRbjabfppvKsQlV0timz',
#  '7DH5dXVuQaqcKf9oTy9oUN',
#  '6Ozp6ac86CSHMik8lbvJuM',
#  '1A6P8IxzNyBRsQualaNXNY',
#  '6CG3BXccaxPwFwymSSJBNy',
#  '08f0fHqZigPgPHCfRjk8SC',
#  '7GCNh1ibQiae8aimaEUOFq',
#  '0e05wFNr6zg1ULcp4NKs1p',
#  '1WzAeadSKJhqykZFbJNmQv',
#  '59KLbEPx6oU0fdwtTVaQAw',
#  '57i0MaWyZGlWxEvNUxTMZK',
#  '5HywRUoXNfWpiR1dAwoZip',
#  '7hBrO5jpSGEbd9X6zxGxQI',
#  '0b9djfiuDIMw1zKH6gV74g',
#  '79nJj5dMyTsUzKvN5jUXsJ',
#  '6GBUsjHfZuweYf5lQEz6mP',
#  '4H1POasJbrLNaQirsIH29e',
#  '28efjJXBm1CuCmqle5HK2w',
#  '4wX0h5Ywx8oIe94PshTv9o',
#  '0Nu9WA8kEbBWEsay2s8Q0U',
#  '5bA26v8eeZrbHJpD4YPKAX',
#  '5EYWGM3Ns3iYew8ws0FatB',
#  '7nDoBWDvf02SyD8kEQuuPO',
#  '0dJ5V9MpWexOq1nRDO2JY2',
#  '6n3VD8CbR307p1e4RECHHb',
#  '0r8iDf65NHgFgZOGLwj5r8',
#  '2Nj2RTsHJsBKZaCuKQqcg8',
#  '4sDiJmHNcm0wLTH8ns65va',
#  '3dAgQFdruU8ufWc5GE05xC',
#  '0dc0eU5THc1uE0Q0KV73XN',
#  '0QswJbk01Wu6xzZ9x7Xhln',
#  '15qBdyeOsal1QJvB3ysW9g',
#  '6yfkS5EStKiKLMNY27dvqL',
#  '0NyMrtH8mUuvtJjEpESn7J',
#  '4vcHOxfV846dVjyToPFBRp',
#  '5jFid6SUnYqohvNvNuZvIz',
#  '7GjmzKbriJewFNDPJtVjey',
#  '7b7ch5lDx13Jwm2623CxJS',
#  '0cJJFg7Wv8moeq1JMd1xPv',
#  '3b7CDTKB0SRTmQ6ytYi5vZ',
#  '76BuIHRNV8KDdrYveZBOOa',
#  '2ejzZzYYXIeo5thfL506Xs',
#  '6IC6VhpV7D8T1t037Atqpu',
#  '0TD22Pd8CsaLwMWMhzUusU',
#  '0NLBwQBYJhEM9t3KAMPFVR',
#  '65UCejW01DAovmluVYHWAt',
#  '2fxjDPEGxXpPvp7uiSi5qN',
#  '2OXidlnDThZR3zf36k6DVL',
#  '6gS6XQ4OqMddkgzHNz40E5',
#  '001UkMQHw4zXfFNdKpwXAF',
#  '4cIGNFaKpoVuJfVvixS0mU',
#  '1tF370eYXUcWwkIvaq3IGz',
#  '1xDm4Oo1aY0yXtrnYUAAUb',
#  '3Qe097eJNp9MfpT2PieEw0',
#  '4pP5xVUYEZljcmfyYFQXsx',
#  '0mSywazXcVFQZRk2Gg9ImX',
#  '2WQAknZHrJAEQOFXe0F44P',
#  '4DkA3DNGcEAh5SztzpTxPh',
#  '295bGNXW52O8kQS2qX9Odg',
#  '3SRuODYNV4j2ckkJ9Samju',
#  '3ODF56f90W3qxDqxHAUi3v',
#  '7o68KX6XyCS9lydBTH6TCP',
#  '470TV9eqeKpuXiOd4NbNsN',
#  '5MkOctZG8LI9uHzpY7ncWj',
#  '6VZCuvHwk3xmjwgKga0bNi',
#  '5SpoN8sCoc05RfVde4raGN',
#  '4eH47ofIZbrbKwmLJSu5hb',
#  '2pf63Aa47XDtTIkfKbZc7I',
#  '0pdfN7nOHMYmKykzu1cyfm',
#  '6Ss6vCdWHgCuiB3icgBAwY',
#  '3wx2kQWPn9p5UppQbNhPAk',
#  '2rKtSHDkql7aZuWKUdSylq',
#  '0Xg68XXMRWzKQvD5S6BFvI',
#  '2p07VcUwRZ5sru3mJ0JogS',
#  '2GFRVCQn8vhDWiwST1alsH',
#  '5pzoq7ggrA0GN3SMjy0NT8',
#  '1ZE0BKf8zRD6DLif1BG9x0',
#  '1l2Xmg54EUr3TDzNIaCr1z',
#  '1EKiQ1InQXuodp4M1idrng',
#  '3mewJ611cPqPIk8EQDiA12',
#  '77dcKrzRUI02XjHd2okARp',
#  '0yD66650JxhqKbW76C2qCo',
#  '7tDazHxWRxunXSloWkHIgN',
#  '0ogTZlmFqg5xyFCMpRAEb4',
#  '4ns2xaym21aBOOUN1vaBPJ',
#  '2gjwUEyO1O8zVunCbItrHu',
#  '539dFCMA8lfEElDPgGpcIB',
#  '2iCJEYdoYbCxFoUg8759nm',
#  '3aCTkhw102uz8NCRZZv1qF',
#  '1nCSr7oGeUv7sUEoYuAJFF',
#  '5vXsj8L4DK1gGQ43BBG028',
#  '0p7QF136UOOUHnyU8CuZra',
#  '6wfTb2he5ANMQSFnlamnyi',
#  '2rmNddZ5XSLhpow3uBHo65',
#  '3eIc0XWlqNkT290DfwNyBJ',
#  '5OusUgzHz6Ulb3GZT7WUo5',
#  '1wb4P4F0sxAQ2KXrRvsx6n',
#  '4hCv07JQHyyOrC72WjeDuF',
#  '1HhXBDM4vhNiOiSU9BBBug',
#  '1vFyOiwgezbBMIFtT4t0it',
#  '6enPOmd3vSFpI4jjms8kXN',
#  '7MYCBhcWtRSJ7YXTfIHlI8',
#  '5BYOLEoFD1fWokKncxz7BQ',
#  '6hIS1u7nuJmFE12rXAPMxm',
#  '3NfexsDdbxMMwfK3VRZChL',
#  '0qrst0xZAZ0NtMtuUcEq0f',
#  '60IGhnH20N82dNxKnc8jDd',
#  '2JqxrHRAtnrkczEZEzAKV2',
#  '4Ng7hGdPwpINleVecBWiOO',
#  '4qkshp4FWe0msInDWTbBlR',
#  '5x6zdbGeaOpX3XeZmz4wck',
#  '5dHm2RIrUncTtoeDaBo76F',
#  '4C5pVpypNmXpSN42rIqmpK',
#  '6ej1QJ8eIYmhsyTlvgDajy',
#  '3OZVqx1YsqDDkxQ6TnmHtn',
#  '6J4Y8Wvb631w5UVxa1xX8T',
#  '1qHRFZE8qykNXYZadzmi1m',
#  '34Vn9nKfztyLco9lJazy4j',
#  '3MoCJ7TOCMlFdyeBEHt24q',
#  '2A7j0RLnzvvlUFrevBiOQf',
#  '33kKQSeqM2ecEcKF0LNSRT',
#  '3qJQtLfi7ztIz7JYDrVHrg',
#  '71gllRzHoMKgU7b2y0OfM7',
#  '2ugGNNwNaJdiusX3aLOMUy',
#  '19DnL1HnJiijuEfaiS0Eus',
#  '32vPOj5lZCgQjMdOE40yKX',
#  '3ts6xK5GzfMAAriT9AIBmP',
#  '3HtCJiLV8GH87AViMtUKhO',
#  '10ps1I1sIMRNZW11eceN7W',
#  '3awuorsQsio2PUOvzq3hpd',
#  '4cDWuDOQPJsnS88XKrkAFy',
#  '68Ckgc2wYxjSlgam1Rbe6A',
#  '7uLQTOxQ3nwwoHuxwt2AHJ',
#  '7CNd7rjfVt74TFlcOcnZgN',
#  '7JiCaZ93B0hdj3XwFqwn4W',
#  '7DkzLcSXS4KhSvbvIJja3M',
#  '52PGtJuGEFNVOnRdLac1Av',
#  '3ZgrRbLGUtmtzmubeiRRIb',
#  '208bYsadJ56km31IENM2qS',
#  '0JkIre0YxNmKGMU5V7ZiDx',
#  '5d98TnYzxQmFE4vKgzWXuT',
#  '1rkpNfn7l4PcAreJwht9JO',
#  '5wKaxpvqXq95IaoAVPLgoi',
#  '1PB2PGMnYGk3KgsyCrJNVB',
#  '1A0I5aiVZRwecRlbQcweBh',
#  '5pemEFax3jfocz4FGHa3UC',
#  '3NltWS8Xv1pwtBWo1rO7DH',
#  '61EQfJXizp4MIpLYWyLoQI',
#  '4YjjNHtEsTX6Af4mCTupT5',
#  '2PxHwpXwyaYKelKNTwExYo',
#  '7A5CReD6yWe0rrkJym34QI',
#  '2P9Cn8LEt0mK0WD6iCYokP',
#  '0PEoDuSyUrSFFjV7XmY58P',
#  '2QS8C4T3H1hYpnADMpq8Uz',
#  '4H2TRR9FjnnIwxGnIt9stO',
#  '0lZxd99ZIjA0zUdQAY3FXr',
#  '33LQxf2T3Jbgw3XQ1H3LMY',
#  '2BPiamp7M8ARGtxjNyTZWf',
#  '3kg4W7OIAVSNTLjXArK0Kn',
#  '2dWCrXAgzncrnIOEzMTF8l',
#  '3c9WJhG3QvTtHmwKb5wz3i',
#  '1fYypIR0kaFzaSRbzvtjl9',
#  '43H3q2NWT9LCuYS1B5IUvV',
#  '1YaPhbIo2oKWT5ejlMEL5Z',
#  '7rlrchnrrET1oW50KAYV3h',
#  '50PU05RTGva8laKDwxED9Y',
#  '6BJOQ94yeGXYwuR6X9QO1N',
#  '7nIcb2zJj0HPNws3PRCl7k',
#  '5M8oqeozsjPMSXbkjo0SyD',
#  '2bYp7DYfjXULM24FUh9Z3Q',
#  '04rZkq3ihHmGNfKPgBiTX1',
#  '4kW1AWi4wFNWTyetHs6xdO',
#  '4kY7rYtE4OQkJNq22OIYRI',
#  '2m60tYpmxxYR5em1hZwplh',
#  '1TZ4xBavEWYZaSGPuZTtXr',
#  '3VCWhe7AtBrkhour9t6dq6',
#  '5KW0yv8MLurjPifL8pajWn',
#  '3CrmgANkKOSLPl2uHTqzKl',
#  '6H7nDglS6xWpRidbhMwI2L',
#  '3gJYzy6nRvEFZPDpf074jG',
#  '0ZUo4YjG4saFnEJhdWp9Bt',
#  '0svhKL5JfIxASjbmEkxXKV',
#  '5wane5dFpp8xgriui6y0c7',
#  '4zzcta2PO7TIs9YuXZ6G2u',
#  '6BCrbWBpb8d6KWmEqZ41tr',
#  '5wg3ipiZ8RqpEIIVWRknUf',
#  '5Jc5FzzI9xN8cYDiKlKpr1',
#  '5zGqTc1WQUe8XqqdnrpKTV',
#  '5A3PWXcB0sFVjOVAYLQR2h',
#  '2mXsZsJBThTaJXbNcg5QD4',
#  '3IvcWWehbBcBR4YZxlGM9R',
#  '2NPjXgWmTmpKg5lelNUDDQ',
#  '2YVCkTYJpv5jelYrHYoEG8',
#  '6QHGdUv7dGs8qB5Kok7UZL',
#  '53Dj5PCDhb22qWqmre3YQs',
#  '4W3QcMXjWVYEiNe4khtNUF',
#  '6aUhfNWYnMThF3TGtuYUUu',
#  '4jE0JNXJ2H3UdhoYBeu8st',
#  '5zMy6fM0mZebBMBZQuAVEA',
#  '2h5a6t9JFasqH5WJFPbmGL',
#  '62LwrIfpXJNc8uhnbACBvl',
#  '6Ymvlzom4TQeoKqAWsZRD8',
#  '2kR18wsL3gvXRXdNE4dCGc',
#  '65N3RYCN1DgfY0Zcv5k9kr',
#  '29ZJSsfmcSJcShl44iXuP1',
#  '7LvK43IERbcLsuabmyKQgi',
#  '37JPdGgYcQAJSElj5boJx8',
#  '7nyjRWYY6R98A7qupjv3Lm',
#  '2Gy3XMLbBxACZ4tXdFRGr7',
#  '5cCLKP66G2PJEorzYQVXHR',
#  '1KhrAWvLIjRlQIJtSTgvsi',
#  '3N0jGYbGjlfxAPPOQ3m1x5',
#  '5JkGBzxQ6qqf6MSzuLnjV2',
#  '736KP0gdltJQWPKk0wVL7l',
#  '2kzVFcp3kSU1Qld4dYBM7L',
#  '2TIEeLrOQrGnO2D2OeDDJu',
#  '7AHw9SfOITU9Q7sj3V5vxV',
#  '7Jpclr7tZ6aQXjoKzWXUJV',
#  '3QvOV1QYPPre7gjppKyeON',
#  '0cV4xwUA4ue2deqq4CZFko',
#  '11QUG7teTcHUXgP1KsdvuX',
#  '6aPc6SSWgTsiXrrUpJCPlj',
#  '7puxIVNdj5nsBJk43zM3bH',
#  '0IdSezptoRChPUve2I2fEM',
#  '30ZGbfPsjDNCgL21Qzciuj',
#  '50phHfLArbq0sD1NlaZAhq',
#  '3fDsErbmOD3TuaSDuxSXav',
#  '0vF93CIaoyM4g4R5KofEUw',
#  '5nWgEBtaRwVrCMjer1RtLm',
#  '0Mur5jhkaTCaSbLZgx5fb3',
#  '1PpbrbgsXRXeKw1GnZMEv7',
#  '0vZvEE9c2bmA6H8hVKxXEZ',
#  '2SpEHTbUuebeLkgs9QB7Ue',
#  '6Ray43gNA6LZxareyESwNk',
#  '1mICUTQCbRkAvGmO0cwoAz',
#  '6dW1eNvvUJ3ewOTSnYtRgR',
#  '5Ho3mmGfq1q6GyqXhAyy2J',
#  '4xInIiKipU1mtUogJ3ZdYr',
#  '7BCgPuJDZgPwOv1E4p6Cvq',
#  '4NAc9cy1lvdTRJgiCagUeo',
#  '35zwqAY2glpqDm9PM5h9el',
#  '1TKlBK9cSrM5u4CiL4SETS',
#  '2rjeRpzY5eKn2zZMwAfuod',
#  '4LE5mk1mDDn0TX7669wVvg',
#  '7kWeSMXLxUHHOkFxsS0vhP',
#  '5Z53DsDtQ3H474nRstsksf',
#  '3jc0BIzhjQO96AUgl0WQW8',
#  '2q49JWdTqa951SdCXZW44g',
#  '4CIaUS9qVxS6RsQBnC37EU',
#  '31qE8JaRGoHtzo4YOuZi5i',
#  '1TanmIWbaUj5NVwJ3k4XPd',
#  '2iT8p5HHGZoIgFME97V1fd',
#  '6fTFy2nIb245lkgNLSgK8u',
#  '4elsQHzndSMtjrsbcwnZgf',
#  '0AbYscoIblUGiNqn2Iw6fq',
#  '4sHOAALFZiNa4wukjPSBpq',
#  '6Lst3nF4McKOTLSLuTvLhw',
#  '3wHN3AHKtry9HxqOF6gwwe',
#  '6olKv2HP3XgBpvVxAswowe',
#  '3G67yAAMfGXQvOeNu7h3FJ',
#  '08c3wmdjKSjxTJY9cHSts7',
#  '69j0KoPJuwpnbGWrfn7Yll',
#  '3OMpIoONQH8rSscaZLozFQ',
#  '6cjwec9ii5uLK7CDfPBYt1',
#  '6YkynE63ukqWqd1SWawLPC',
#  '1XdlLIfwryo38EZ7OzdoEG',
#  '0PRJj2AQRKJm0AiZE2CaY7',
#  '5YY64mW5PL5waJKUsIJIQt',
#  '3L6vCuAJNmC87VkARu8tuN',
#  '1vYf97tjbKVPXHK4oQPU0T',
#  '1Fo2N5iXRi37maMboaig7O',
#  '3C3oknuBLo3jxhmRk67glu',
#  '3YskU7Rb5ONzWfe7Unpdax',
#  '3VffiMehjhfqo7XZ5zGpCP',
#  '6KbpvmsV6L8JsON1C3JHAV',
#  '5NBbYPv6iAyrHFnSI1VSBa',
#  '0rK4HCKzv2r1IXqKX3DKpq',
#  '2gFBNU0hoprOypWeEU5D1p',
#  '1eQRW2fZHZI48vuo66YMCM',
#  '4GSN9c1phm6nwhYIelbyn7',
#  '6QUs5z2uEbSGZJpPGMfgQA',
#  '4pFNWAU8e8F32NQkMyLAZi',
#  '7GgtarFx3ognXFQooZ3PyW',
#  '4s9JGX0flu9KcxZziV3I0C',
#  '4lcXNTm9JrQpJYXqsENmFI',
#  '6vgN6KGstss0GnBbKlMNK9',
#  '46d72HjfyfN18PpRNzIRqY',
#  '0M7mWKqwTIaVjYyxfZmtTa',
#  '6uWi4dfFCcBnzzsfKirvio',
#  '7oizkVPKiJYU5CyTjrcVp0',
#  '1g5EcKDECPxeI7kgkvcbxm',
#  '126s9Yi5rRxPt6GEWrmXAF',
#  '2S2dKZqymLiKM89JtQX2ki',
#  '5ZuTYT8bW7HmsjqNDm7TrP',
#  '6EGRx5TVuHAsmy3JKb8SRC',
#  '2ioOpr2HvAMVhuAmDtAV8h',
#  '67S1POEmchWHyss0nboDDN',
#  '1ARdP450XolqoyI7ownYbu',
#  '2rGgjcjiq1JKRISnDuqlTA',
#  '56BG1hMSEkIN7IA2E4xNuN',
#  '3A9jxTBQFZ2p5AjaMhJu6y',
#  '5WEK4szbQp9c7ZK6LkYd9k',
#  '1VnQfAPIHwFImjfO9gnyUt',
#  '4FWq7sBJs7NClaHYDXgMbr',
#  '7B2ETOSXeXPfWQl4gLjcat',
#  '01RVupyBFNuALcAFZjL4FY',
#  '13Oda4GsHXzRAfquxWkrzA',
#  '5c15axZrDZtzqYsomtEwTz',
#  '6RJa6k6LCzyTlP3QXPDJRP',
#  '32jHB7W9b08OTorAqR0cJo',
#  '3JEPfsHlaIfPsB6I8BY4Sl',
#  '5HwAaXDLVDgVcoGIjDRANK',
#  '6Gfmj0HbpvxTdW0sdlzTDU',
#  '0U4R6UqrJo43TmImPku9H8',
#  '4cen5a0z9D3ryLbCte2tCQ',
#  '4l8u5h7OjkZo2UmyUoeKYJ',
#  '7LrZ3SczM7zlUkVlhevPp2',
#  '4raGevWiW8i1gactXulebp',
#  '6z0HjnZ1ZgS71Pp8rUibLC',
#  '1IyktkUQ3ktjlc6eDXG967',
#  '5FIp4LrsffxiHLhmmpCbCx',
#  '57DG9DcC0qHS2zAMYVXys9',
#  '2TPm21kwmgRhx3kJfJmdrB',
#  '1mWAarqhZ3kirI6p0uLzOT',
#  '4etE2X6t7GmyiuYLIdI8H5',
#  '5oheUEVCpJllnImTs5nNiS',
#  '2sRQWq9NELigoO4xRB9s3r',
#  '4g1KdhosR6v8qCT1F1Njev',
#  '2vIEIAq2biseC67LvXb9q8',
#  '0p1HtkrNYxv0iDfEKwXSTp',
#  '5zyTd9wvMWASK3TDJglmDi',
#  '6wkrULQ7AzurQ0KpXzFDbH',
#  '5I7oDuQDfhV0syRU3cU7zB',
#  '32zPvvt7K2nZIbQl7cMM3F',
#  '3Hbm5luuxJheCKJheYAVbZ',
#  '4QoZGQ8woaho94v629kVl1',
#  '3IDK0isTMm8E4ynYqEkqrJ',
#  '54RCDE1TAewECyX4WDUVm1',
#  '3wGoIFHqCl36tu9Ne3guos',
#  '5kDQ02FBkj0Hx7YUGPcuhO',
#  '3duP6mBVDsHM8ioN7o7dAK',
#  '5Lwc3DTWzX6JaW2x2PZezt',
#  '39vRhTRqO7qQggd8aID96o',
#  '2yWtLaPCOUDyi7f1lOXCn5',
#  '16OFkCrdYH524sqvTPt6CT',
#  '1t2hJFgJyUPD2crOafMUEk',
#  '7wL9EVloIobMw22rT7Ve8x',
#  '53AfG8mkV8B0MzfymQmIvj',
#  '6hi6Ypzbl6KXmTeZHTDuKp',
#  '6v45WySfJunAI6kTh3eCpc',
#  '70TsRbycWfabtevnripyRu',
#  '046MBhhgQJJghnbgZCkaAR',
#  '492Xx55i1QQ8fAIJqis5Un',
#  '0RdMBceHhBJLqNjObk1NPP',
#  '2Fs18NaCDuluPG1DHGw1XG',
#  '7hzyuLLHrQALKn7kIAc6cR',
#  '6XD3HMATLswheYevIfKkSi',
#  '51EKPuV1uAWryjNMqZLtgJ',
#  '4zhSO5tu9NduAaq7KxhHhS',
#  '0SCtEUwSkgavjuzebBznX5',
#  '0RbaD2rw0HmpfflXFH9DKu',
#  '7iGdNkROFlxqUJkHNlkoQV',
#  '0eVz2pDxj8Rosxoy8Ma4Fu',
#  '0LBj6HiwpO3eSyo9K7lmBi',
#  '7nJrhBDkUSHASFzopvgygk',
#  '3TZxM3VrkICfKS3tRQNd7X',
#  '0Q45S96loRZtRPZYFaNqB0',
#  '7EemZNAyx3nvkYPVfdeVzC',
#  '3Fa7jdzVHdykpioJP1Qw7Z',
#  '5FVuERsYqtKKAaWe62NBnv',
#  '5Crfmd0ZGarlMUDPqhl7yl',
#  '44xWtabQzBHKXxD0UVLSNQ',
#  '4LFAZqC3a5GKlostZzNvK1',
#  '6tRSJPPrWs1hqOkllIJK9M',
#  '4BaAxwS4VoeCYk9TuXQs7f',
#  '6IItFqIHg6jHleKOYI7Aas',
#  '7bNX2Fgb4MjPrYbkHaCNwV',
#  '0sm3ZtBLGY0Wbz7MOwwmGK',
#  '24SM5UDYgjEzNUcVu2cURV',
#  '5t0pvNISvXLaNIx253Oe2v',
#  '03T4H6czLK426qcW870hBZ',
#  '2WKCH4ISejDV9ad7iPp5XU',
#  '6EJSgsy6cSkGs22HvLbbV2',
#  '65B1tEOv5W294uCKbmEcFV',
#  '0DAVCurdi9ZqkVUKIuikzm',
#  '3FN7JMZaaQ9lSzIaan0YZ1',
#  '1zJRHhb8yN2LyVfNhmlhH0',
#  '5v1bA7NmQcQHvH9IDkeeF4',
#  '7K40sZ0ZV6vGjzSso2nFyr',
#  '7yQMZQeiSKnvEgimeGPVhi',
#  '6E9V9TRlVOLjenGjHemzEH',
#  '1NIUECyq3vHFrWeFGKvESB',
#  '3XKbdb9GB6u3hsnUklQTav',
#  '41JQTDa8BoAFkDluhaOip6',
#  '2bazs0jc6oxEEeFYQXXJxv',
#  '0CKba2KBPP9TFbh5Nf8i4P',
#  '5O0GOy0L0zfDTPv9eIApkg',
#  '5Xc1asNg5VerELR1wFjAey',
#  '1PUrH3l6rfsuZAQdsM4LGY',
#  '3xsYZOaajjyJouOEuKIeo7',
#  '3un2KQUaQ2brEpd8dK93wI',
#  '2bh8uERWXkMYWgWnFI06ZW',
#  '6T7zOXCUuk0DFFUQKs4Wml',
#  '3wgQxL8Ru6k1AE01LIoD5Q',
#  '4u7KjVIQPdzGCcAwg4W5Kl',
#  '4FUfoWMypAyWbOavmYyeNu',
#  '7kzLomClie9HkjgcvfU4FO',
#  '4qjmnM1aYvayCTDd0uuRKH',
#  '1X9I9cisg6m7w5kUO8K8z8',
#  '6xnCYwLujGfMS3zsi6GkC7',
#  '4GWDHnXmJBZfxe3DWZcPmg',
#  '5xH2anpiXRpoGgiD1jB9WU',
#  '7maV3I3KQNYpsOWYTOhGqn',
#  '3vIaH2gly6zqfQOBS9W2sF',
#  '5gCQ3MbnCOHWcBpS8IgViH',
#  '3lEfWXVeo02PI4QaX5ocV9',
#  '7j4fpEVBmPwy9ed8aekYcj',
#  '2ymeOG7mSTMkQke3e3pcgT',
#  '3ulGUOzVCTCorc8m3YMwmL',
#  '5lXX4SAV6HBaVnZ6sUQPNE',
#  '1pZbQrvzJExLxvhYcrsYdG',
#  '7E2DqvnVtbIrFrL5X6YH9Q',
#  '2mEAWmVDub6PSF8pZXInrS',
#  '0slGqrF5FqaDVmYrksgg7f',
#  '7ngLY64yLCFIRaybpIYKJz',
#  '7FtR6v3aRSQc0FrkBdmDea',
#  '5yIiXdLRE85OBiQmCaUenq',
#  '52sHHwI06fjHn8RwMBP61z',
#  '7K4VxvIXXbDbaVn6ARbch1',
#  '6FevJcaJvt5EvsHnuJHBnb',
#  '39FwE8edwuyiaa4PrGBkP7',
#  '3QnNZo9UwBOaQDtT3mcAjh',
#  '1qjl8UJtWTHrk4SFpwftSN',
#  '4LlNoNZflek4hZyZigCxpW',
#  '3rXdABev6vQtBCElztIl7m',
#  '7G6l2FtQyRhQgYgut2I6i8',
#  '7MLwJApVQ7DJkuslbcK7d9',
#  '4BXkf6yww23Vdju7E1fUrn',
#  '0meAc2H0tC5tOTd6MDe0cI',
#  '1dpE6LO73JD8mXXdgP5SqD',
#  '5cQJvxrYIcsYZKJYgHFDzi',
#  '73njvNJmgXA180vTPkA16C',
#  '4pM3FHdiulPKpx5g4GIZg6',
#  '6aNwDe5YH5YUPlpHkku52w',
#  '4S7pVk2135ssA0qiyqpZZp',
#  '5r00wpsojd4mBYaQFDvni7',
#  '3Q9t1A12iUemHTAWnH7PjD',
#  '7BN1AMncxTWhQmS4r0XgQu',
#  '1Nv0CRk2iNXDHWgqH3Tr1z',
#  '1ak2K9SpHCjnDbxmNFxr6P',
#  '7jRdxVZeBAtLXL8ZpBMR2q',
#  '7tSZJ9iI3634Sqtd6Uvl49',
#  '5BtS8w1kkjLV1BbvB0t12u',
#  '39IoZIC8eEirT1v70rqSPq',
#  '7rDcULv8vV16vetBjPJhuE',
#  '7njoWVpJbAiTkyT6rKwbze',
#  '6h1hXgfN7Mzw8e9Afjibcc',
#  '3sZ8bjYNRyLe6VccV8znB0',
#  '4iLPK8QnOvqm0Azbsk2GDn',
#  '40e31PdTiS5oAorpANQXc4',
#  '1hh3iFX5vVsiD9LMwUlQeh',
#  '4ipZsAA3YuqCDSXiPoEGIv',
#  '5FxgRnXBHMM0q4stwqrjjM',
#  '6Sr2e5J7WnRJ7sLpUpyie9',
#  '60hGQrn24APqEFSLObLeDc',
#  '69m9WDPBvemwujQwdONslk',
#  '0wBfrbqDpIukerUWZzllgk',
#  '289hx4t6fH2BBe8p6cnXo1',
#  '5dNJatz0iFlprRjdUogb5C',
#  '2RB2xSlVoMRhINO0SruNIx',
#  '3VLCtStwYsAL4LKZgeUvy3',
#  '4kGwf8ArBjC8AZRNbahDxk',
#  '3M31S6f0z8S3nkFh3eS06W',
#  '13kfQhv7drKlGtbfSz0H0u',
#  '0158TMiGmHyibaDeaUKayX',
#  '3EO5DSiJSASa69I7Vv00gN',
#  '13zhyZhlM0VzUpEW8aShcp',
#  '1N9GGOUf8TQqsaPDByZzEF',
#  '5aj0xPGiEUN3aI2oOYu14S',
#  '0lNLXEMPtGhEpbgwQfo0c1',
#  '1giXJuK615CD5PbyEvR6K1',
#  '1zvQt99d5oTkEQLmSoO1yu',
#  '6stD0CS3QFs2yY3CoBfK8K',
#  '20aorkzugOSwPcXGZf9eCv',
#  '0eHT8N5YQglv8cYYizXvSw',
#  '7A7gHOXvDJ12CRfiZ18Uro',
#  '5UzU0qw21okODBNUnxptVo',
#  '4Q12UTuXoMqpBro4p0VXQg',
#  '5I7a2zThNmOtlbwrRlcN88',
#  '1VdHooAMVaGXPSty8pifv9',
#  '0gLy1JjZc7sUeMhBnHDmlF',
#  '4wDpjRQOvOHXE9AtNWpdVQ',
#  '4s6Q9zPmiYcpo5MR7uoVnt',
#  '27aDju7VAODvQYHWrrv6o9',
#  '2j79NtwxoWDmkiH4MGwdLq',
#  '42cDyuTfjSIuDSqrRwC1Mc',
#  '6NrUzuNell8qCfuNoSgey4',
#  '4iYQUKxKwOOm6X2R7ALPix',
#  '5je7nvdte7odjJvs5iM1bS',
#  '7yIDuoUFaiQaIZsYgLCysF',
#  '6VUXsWN3aNqEhaPawlFjep',
#  '0JcKdUGNR7zI4jJDLyYXbi',
#  '5oUjEriN3FJRtOy9pfHML5',
#  '5xErd5QhOvTKFU7l8dffWC',
#  '0J6dezPhTa0ePaN87kphCs',
#  '2VPnnOGXmejtKqxGY4jg66',
#  '6aVtUiEKsDkRj6OXEwjkyV',
#  '7fJaL74toBMoNuO7iUXsST',
#  '7g8OpS827dAYU067lZaR0L',
#  '20DVVHFczaYBWhJ8utqmHb',
#  '3E6t25sxh6v5FDSfIVIAOz',
#  '51T2SPBH4YjbrFJE94NJT6',
#  '1qX7cD42VEs6zgMIBbFlCO',
#  '1hc31O4qhv2tnSnW1290KC',
#  '6BkK5Dsu1kTne7Cn6EyYex',
#  '7MevrbPAGEaw1IgkaBmv82',
#  '6BAElGWC4djQgebYypJqTl',
#  '7wqMZWYeBxJt0obQPnF5NX',
#  '2g0BAZVaLlK8GeTVzF6hQ6',
#  '4whYDpJ5XVQpmvecbEHP5Q',
#  '3byhGb1jyYOj8uNhA1UXoO',
#  '2TFy9ApipAVliib16vwWTc',
#  '3onPZQxZ9igu7plus3rK7D',
#  '1ESipSqVefdknPg5IBKFND',
#  '1wtcyTExLF8nZu9ZphHIl1',
#  '28NvPQZ8XVVlV2eGmUw2Za']

# %%
print(len(track))
print(len(artist))
print(len(track_id))
# Out:
# 747
# 747
# 747

# %% [markdown]
# ### Combining data

# %%
# each list becomes a column
track_db = pd.DataFrame({'title':track,
                         'artist':artist,
                         'id':track_id})
track_db.head()
# Out:
#                          title                          artist  \
# 0       Crazy - Single Version    Patsy Cline, The Jordanaires
# 1          Folsom Prison Blues  Johnny Cash, The Tennessee Two
# 2       I Will Always Love You                    Dolly Parton
# 3                  Springsteen                     Eric Church
# 4  He Stopped Loving Her Today                    George Jones
#
#                        id
# 0  3zpj9dvJABiyMrmLCPw6i8
# 1  121sjkub4p4zcFNozkKnQD
# 2  6nRvgo4ySezQKD1D7NIqAu
# 3  05ZACkzW8YbRq3eFgIfSNB
# 4  6qMgx8ys4MNNxypaIvbG0i

# %%
def append_info(playlist_id):
    new_track_list = get_playlist_tracks("spotify", playlist_id)
    new_artist_list = get_artists_from_playlist(playlist_id)
    new_track=[]
    new_artist=[]
    new_track_id=[]
    for i in range(0, len(new_track_list)):
        new_track.append(new_track_list[i]['track']['name'])
    for i in new_artist_list:
        new_artist.append(", ".join(i))
    for i in range(0, len(new_track_list)):
        new_track_id.append(new_track_list[i]['track']['id']) 
    new_df = pd.DataFrame({'title':new_track,
                         'artist':new_artist,
                         'id':new_track_id})
    new_track_db = track_db.append(new_df)
    return new_track_db

# %%
test_list = ["abc","def"]

# %%
append_info("7KMtxb9kh3TtVvJTdLtJ2K")
# Out:
#                    title                   artist                      id
# 0               Santeria                  Sublime  2hnMS47jN0etwvFPzYk11f
# 1     Livin' On A Prayer                 Bon Jovi  37ZJ0p5Jm13JPevGcx4SkF
# 2    Sweet Child O' Mine            Guns N' Roses  7snQQk1zcKl8gZ92AnueZW
# 3             What I Got                  Sublime  3B4q6KbHbGV51HO3GznBFF
# 4     Kickstart My Heart              Mötley Crüe  6imjJij6aCM0IbbODUzJQn
# ..                   ...                      ...                     ...
# 995    Too Fast For Love              Mötley Crüe  7mJ9n1EaruTwLbgcQC5AGp
# 996            Jailhouse                  Sublime  01ZoBkMJAxjPx5gQcNR7Yl
# 997             Shake Me               Cinderella  1Qjpl8Kav6rrO92ZuG0OK8
# 998            This Love                  Pantera  0Yfpc5zHc9pElVCQ1bPlF4
# 999        Dot Your Eyes  Five Finger Death Punch  6lvtWK82l7aQmIGbC1yJfY
#
# [2000 rows x 3 columns]

# %%
append_info("4VXFwpNvQysB8yS6E2t2ls")
# Out:
#                               title                             artist  \
# 0            Crazy - Single Version       Patsy Cline, The Jordanaires
# 1               Folsom Prison Blues     Johnny Cash, The Tennessee Two
# 2            I Will Always Love You                       Dolly Parton
# 3                       Springsteen                        Eric Church
# 4       He Stopped Loving Her Today                       George Jones
# ..                              ...                                ...
# 995                        Jealousy                     Martin Solveig
# 996         Rise - Lushington Remix  Miura Keys, Raphaella, Lushington
# 997                    Make Me Feel                        John Summit
# 998  Out Of Control - Pat Vocal Mix                       Lupe Fuentes
# 999                        Infinity                       Infinity Ink
#
#                          id
# 0    3zpj9dvJABiyMrmLCPw6i8
# 1    121sjkub4p4zcFNozkKnQD
# 2    6nRvgo4ySezQKD1D7NIqAu
# 3    05ZACkzW8YbRq3eFgIfSNB
# 4    6qMgx8ys4MNNxypaIvbG0i
# ..                      ...
# 995  1u4HCtZ0iI8P8Bb4YcGuYP
# 996  2BjeIyXzFtM8s929gzXSvN
# 997  4vgP9RNzsXEUcW7Ws50VrI
# 998  1QqON1dtjcsi2As0asNDQK
# 999  2zVVoSwUhZuOV0biyFJK8R
#
# [1747 rows x 3 columns]

# %%
playlist_rock = sp.user_playlist_tracks("spotify", "7KMtxb9kh3TtVvJTdLtJ2K",market="GB")
playlist_house = sp.user_playlist_tracks("spotify", "4VXFwpNvQysB8yS6E2t2ls",market="GB")
playlist_classicals = sp.user_playlist_tracks("spotify", "1h0CEZCm6IbFTbxThn6Xcs",market="GB")
playlist_dance = sp.user_playlist_tracks("spotify", "794tEP1QrKMcaQcFmEyFst",market="GB")
playlist_hiphop = sp.user_playlist_tracks("spotify", "0agbFCQZvK4q9WR0d4Iqcj",market="GB")
playlist_pop = sp.user_playlist_tracks("spotify", "2YRe7HRKNRvXdJBp9nXFza",market="GB")
playlist_jazz = sp.user_playlist_tracks("spotify", "7g2KyiE9RI5F1fV60OIUu4",market="GB")
